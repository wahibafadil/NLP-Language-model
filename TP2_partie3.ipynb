# %%
import urllib.request

url_train = "https://raw.githubusercontent.com/qanastek/ANTILLES/main/ANTILLES/train.conllu"
url_dev = "https://raw.githubusercontent.com/qanastek/ANTILLES/main/ANTILLES/dev.conllu"
url_test = "https://raw.githubusercontent.com/qanastek/ANTILLES/main/ANTILLES/test.conllu"

urllib.request.urlretrieve(url_train, "train.conllu")
urllib.request.urlretrieve(url_dev, "dev.conllu")
urllib.request.urlretrieve(url_test, "test.conllu")
# Out:
# ('test.conllu', <http.client.HTTPMessage at 0x1ed18e6b9d0>)

# %%
def extract_sentences(filepath):
    with open(filepath, 'r', encoding='utf-8') as f:
        sentences = []
        sentence = []
        for line in f:
            line = line.strip()
            if len(line) == 0:
                if len(sentence) > 0:
                    sentences.append(sentence)
                    sentence = []
            else:
                tokens = line.split('\t')
                if len(tokens) >= 4:
                    sentence.append((tokens[1], tokens[3]))
        if len(sentence) > 0:
            sentences.append(sentence)
        return sentences

train_sents = extract_sentences('train.conllu')
dev_sents = extract_sentences('dev.conllu')
test_sents = extract_sentences('test.conllu')

# %%
dev_sents
# Out:
# [[('Aviator', 'PROPN'),
#   (',', 'PUNCT'),
#   ('un', 'DINTMS'),
#   ('film', 'NMS'),
#   ('sur', 'PREP'),
#   ('la', 'DETFS'),
#   ('vie', 'NFS'),
#   ('de', 'PREP'),
#   ('Hughes', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('études', 'NFP'),
#   ('durent', 'VERB'),
#   ('six', 'CHIF'),
#   ('ans', 'NMP'),
#   ('mais', 'COCO'),
#   ('leur', 'DET'),
#   ('contenu', 'NMS'),
#   ('diffère', 'VERB'),
#   ('donc', 'ADV'),
#   ('selon', 'PREP'),
#   ('les', 'DET'),
#   ('Facultés', 'NOUN'),
#   ('.', 'YPFOR')],
#  [('Mais', 'COCO'),
#   ('comment', 'ADV'),
#   ('faire', 'VERB'),
#   ('dans', 'PREP'),
#   ('un', 'DINTMS'),
#   ('contexte', 'NMS'),
#   ('structurellement', 'ADV'),
#   ('raciste', 'ADJMS'),
#   ('?', 'PUNCT')],
#  [("L'", 'DET'),
#   ('«', 'PUNCT'),
#   ('oasis', 'NFS'),
#   ('de', 'PREP'),
#   ('vie', 'NFS'),
#   ('»', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('dans', 'PREP'),
#   ('un', 'DINTMS'),
#   ('milieu', 'NMS'),
#   ('où', 'ADV'),
#   ('règne', 'VERB'),
#   ("l'", 'DET'),
#   ('obscurité', 'NFS'),
#   ('totale', 'ADJFS'),
#   ('et', 'COCO'),
#   ('une', 'DINTFS'),
#   ('pression', 'NFS'),
#   ('hydrostatique', 'ADJFS'),
#   ('importante', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('est', 'AUX'),
#   ('riche', 'ADJFS'),
#   ('et', 'COCO'),
#   ('varié', 'ADJMS'),
#   (':', 'PUNCT'),
#   ('les', 'DET'),
#   ('chercheurs', 'NMP'),
#   ('y', 'PPOBJMP'),
#   ('découvrent', 'VERB'),
#   ('de', 'DET'),
#   ('nouvelles', 'ADJFP'),
#   ('espèces', 'NFP'),
#   ('de', 'PREP'),
#   ('bivalves', 'NMP'),
#   (',', 'PUNCT'),
#   ('de', 'PREP'),
#   ('poissons', 'NMP'),
#   (',', 'PUNCT'),
#   ('de', 'PREP'),
#   ('crustacés', 'NMP'),
#   (',', 'PUNCT'),
#   ('de', 'PREP'),
#   ('poulpes', 'NMP'),
#   ('dans', 'PREP'),
#   ('des', 'DET'),
#   ('zones', 'NFP'),
#   ('pensées', 'VPPFP'),
#   ("jusqu'", 'PREP'),
#   ('alors', 'ADV'),
#   ('désertiques', 'ADJFP'),
#   ('.', 'YPFOR')],
#  [('Travail', 'NMS'),
#   ('de', 'PREP'),
#   ('très', 'ADV'),
#   ('grande', 'ADJFS'),
#   ('qualité', 'NFS'),
#   ('exécuté', 'VPPMS'),
#   ('par', 'PREP'),
#   ('un', 'DINTMS'),
#   ('imprimeur', 'NMS'),
#   ('artisan', 'NMS'),
#   ('passionné', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('Rajesh', 'PROPN'),
#   ('Bhagwan', 'XFAMIL'),
#   ('(', 'PUNCT'),
#   ('secrétaire', 'NMS'),
#   ('général', 'ADJMS'),
#   ('responsable', 'ADJMS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('organisation', 'NFS'),
#   (')', 'PUNCT'),
#   ('et', 'COCO'),
#   ('Steve', 'PROPN'),
#   ('Obeegadoo', 'XFAMIL'),
#   ('(', 'PUNCT'),
#   ('secrétaire', 'NMS'),
#   ('général', 'ADJMS'),
#   ('responsable', 'ADJMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('projets', 'NMP'),
#   ('politiques', 'ADJMP'),
#   (',', 'PUNCT'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('renouveau', 'NMS'),
#   ('intellectuel', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('formation', 'NFS'),
#   ('et', 'COCO'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('relations', 'NFP'),
#   ('internationales', 'ADJFP'),
#   (')', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ('lutte', 'VERB'),
#   ('pour', 'PREP'),
#   ('échapper', 'VERB'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('tueurs', 'NMP'),
#   ('à', 'PREP'),
#   ('ses', 'DET'),
#   ('trousses', 'NFP'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('compagnies', 'NFP'),
#   ('aériennes', 'ADJFP'),
#   ('à', 'PREP'),
#   ('bas', 'ADJ'),
#   ('coût', 'NMS'),
#   ('ne', 'ADV'),
#   ('connaissent', 'VERB'),
#   ('pas', 'ADV'),
#   ('la', 'DETFS'),
#   ('crise', 'NFS'),
#   ('.', 'YPFOR')],
#  [("C'", 'PDEMMS'),
#   ('est', 'AUX'),
#   ('véritablement', 'ADV'),
#   ('pour', 'PREP'),
#   ('le', 'DETMS'),
#   ('futur', 'ADJMS'),
#   ('baptisé', 'VPPMS'),
#   ('un', 'DINTMS'),
#   ('changement', 'NMS'),
#   ('de', 'PREP'),
#   ('cap', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('gouvernement', 'NMS'),
#   ('français', 'ADJ'),
#   ('a', 'AUX'),
#   ('fait', 'VPPMS'),
#   ('encore', 'ADV'),
#   ('une', 'DINTFS'),
#   ('fois', 'NFS'),
#   ("l'", 'DET'),
#   ('objet', 'NMS'),
#   ('de', 'PREP'),
#   ('sévères', 'ADJMP'),
#   ('reproches', 'NMP'),
#   ('quant', 'ADV'),
#   ('à', 'PREP'),
#   ('son', 'DET'),
#   ('soutien', 'NMS'),
#   ('inconditionnel', 'ADJMS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Maroc', 'PROPN'),
#   ('dans', 'PREP'),
#   ('le', 'DETMS'),
#   ('dossier', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Sahara', 'PROPN'),
#   ('occidental', 'ADJMS'),
#   ('qui', 'PREL'),
#   ('oppose', 'VERB'),
#   ('ce', 'PDEMMS'),
#   ('dernier', 'ADJMS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Front', 'PROPN'),
#   ('Polisario', 'XFAMIL'),
#   ('depuis', 'PREP'),
#   ('35', 'CHIF'),
#   ('ans', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Mais', 'COCO'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('SMIC', 'PROPN'),
#   ("n'", 'ADV'),
#   ('est', 'AUX'),
#   ('pas', 'ADV'),
#   ('un', 'DINTMS'),
#   ('outil', 'NMS'),
#   ('de', 'PREP'),
#   ('référence', 'NFS'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('Abime', 'NMS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('abime', 'NMS'),
#   ('de', 'PREP'),
#   ('Vladimir', 'PROPN'),
#   ('Holan', 'XFAMIL'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('Maison', 'NFS'),
#   ("d'", 'PREP'),
#   ('Arrêt', 'NMS'),
#   ("d'", 'PREP'),
#   ('Avignon', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('2001', 'CHIF'),
#   (')', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('On', 'PINDMS'),
#   ('retrouve', 'VERB'),
#   ('ici', 'ADV'),
#   ('une', 'DINTFS'),
#   ('touche', 'NFS'),
#   ('très', 'ADV'),
#   ('melvillienne', 'ADJFS'),
#   ('et', 'COCO'),
#   ('qui', 'PREL'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('lieu', 'NMS'),
#   ('de', 'PREP'),
#   ('souligner', 'VERB'),
#   ('la', 'DETFS'),
#   ('thématique', 'NFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('livre', 'NMS'),
#   ('y', 'PPOBJMS'),
#   ('ajoute', 'VERB'),
#   ('du', 'DINTMS'),
#   ('sens', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Louis', 'PROPN'),
#   ('Bastien', 'XFAMIL'),
#   ('(', 'PUNCT'),
#   ('né', 'VPPMS'),
#   ('le', 'DETMS'),
#   ('26', 'CHIF'),
#   ('octobre', 'NMS'),
#   ('1881', 'CHIF'),
#   ('à', 'PREP'),
#   ('Paris', 'PROPN'),
#   ('et', 'COCO'),
#   ('mort', 'VPPMS'),
#   ('le', 'DETMS'),
#   ('13', 'CHIF'),
#   ('août', 'NMS'),
#   ('1963', 'CHIF'),
#   ('à', 'PREP'),
#   ('Châteauroux', 'PROPN'),
#   (')', 'PUNCT'),
#   ('est', 'AUX'),
#   ('un', 'DINTMS'),
#   ('coureur', 'NMS'),
#   ('cycliste', 'ADJMS'),
#   ('et', 'COCO'),
#   ('escrimeur', 'NMS'),
#   ('français', 'ADJ'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('début', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('XXe', 'ADJMS'),
#   ('siècle', 'NMS'),
#   (',', 'PUNCT'),
#   ('dont', 'PREL'),
#   ('la', 'DETFS'),
#   ('spécialité', 'NFS'),
#   ('était', 'AUX'),
#   ('le', 'DETMS'),
#   ('cyclisme', 'NMS'),
#   ('sur', 'PREP'),
#   ('piste', 'NFS'),
#   ('.', 'YPFOR')],
#  [("C'", 'PDEMMS'),
#   ('est', 'AUX'),
#   ('sur', 'PREP'),
#   ('sa', 'DET'),
#   ('liste', 'NFS'),
#   ("qu'", 'COSUB'),
#   ('il', 'PPER3MS'),
#   ('sera', 'AUX'),
#   ('réélu', 'VPPMS'),
#   ('en', 'PREP'),
#   ('2005', 'CHIF'),
#   ('et', 'COCO'),
#   ('en', 'PREP'),
#   ('2009', 'CHIF'),
#   (',', 'PUNCT'),
#   ('bénéficiant', 'VERB'),
#   ('également', 'ADV'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('soutien', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Hezbollah', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('En', 'PREP'),
#   ('1872', 'CHIF'),
#   (',', 'PUNCT'),
#   ('quand', 'COSUB'),
#   ('les', 'DET'),
#   ('Georgiens', 'PROPN'),
#   ('ont', 'AUX'),
#   ('repris', 'VERB'),
#   ('les', 'DET'),
#   ('commandes', 'NFP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('gouvernement', 'NMS'),
#   (',', 'PUNCT'),
#   ('Barnett', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('qui', 'PREL'),
#   ('avait', 'AUX'),
#   ('été', 'AUX'),
#   ('réélu', 'VPPMS'),
#   ('par', 'PREP'),
#   ('ce', 'PDEMMS'),
#   ('point', 'NMS'),
#   (')', 'PUNCT'),
#   ('a', 'AUX'),
#   ('rapporté', 'VPPMS'),
#   ('le', 'DETMS'),
#   ('sceau', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Comprenant', 'VERB'),
#   ('six', 'CHIF'),
#   ('sommets', 'NMP'),
#   ('dont', 'PREL'),
#   ('un', 'DINTMS'),
#   ('point', 'NMS'),
#   ('culminant', 'VERB'),
#   ('à', 'PREP'),
#   ('2 001', 'CHIF'),
#   ('mètres', 'NMP'),
#   ('et', 'COCO'),
#   ('une', 'DINTFS'),
#   ('arrivée', 'NFS'),
#   ('en', 'PREP'),
#   ('altitude', 'NFS'),
#   (',', 'PUNCT'),
#   ("c'", 'PDEMMS'),
#   ('est', 'AUX'),
#   ('une', 'DINTFS'),
#   ('étape', 'NFS'),
#   ('typique', 'ADJFS'),
#   ('de', 'PREP'),
#   ('montagne', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Johnson', 'PROPN'),
#   ("s'", 'PREF'),
#   ('appuyait', 'VERB'),
#   ('sur', 'PREP'),
#   ('une', 'DINTFS'),
#   ('unique', 'ADJFS'),
#   ('forme', 'NFS'),
#   ('de', 'PREP'),
#   ('rhétorique', 'NFS'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('sa', 'DET'),
#   ('«', 'PUNCT'),
#   ('réfutation', 'NFS'),
#   ('»', 'PUNCT'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('immatérialisme', 'NMS'),
#   ('de', 'PREP'),
#   ('George', 'PROPN'),
#   ('Berkeley', 'XFAMIL'),
#   ('est', 'AUX'),
#   ('restée', 'VPPFS'),
#   ('célèbre', 'ADJFS'),
#   (':', 'PUNCT'),
#   ('Berkeley', 'PROPN'),
#   ('affirmait', 'VERB'),
#   ('que', 'COSUB'),
#   ('la', 'DETFS'),
#   ('matière', 'NFS'),
#   ("n'", 'ADV'),
#   ('existait', 'VERB'),
#   ('pas', 'ADV'),
#   ('mais', 'COCO'),
#   ('semblait', 'VERB'),
#   ('seulement', 'ADV'),
#   ('exister', 'VERB'),
#   (';', 'PUNCT')],
#  [('Le', 'DETMS'),
#   ('poème', 'NMS'),
#   ('en', 'PREP'),
#   ('prose', 'NFS'),
#   ('est', 'AUX'),
#   ('né', 'VPPMS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('XIXe', 'ADJMS'),
#   ('siècle', 'NMS'),
#   ('avec', 'PREP'),
#   ('le', 'DETMS'),
#   ('recueil', 'NMS'),
#   ('de', 'PREP'),
#   ('poèmes', 'NMP'),
#   ('Gaspard', 'PROPN'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('nuit', 'NFS'),
#   ("d'", 'PREP'),
#   ('Aloysius', 'PROPN'),
#   ('Bertrand', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [('Son', 'DET'),
#   ('dernier', 'ADJMS'),
#   ('film', 'NMS'),
#   (',', 'PUNCT'),
#   ('avec', 'PREP'),
#   ('Ewan', 'PROPN'),
#   ('McGregor', 'XFAMIL'),
#   ('et', 'COCO'),
#   ('Pierce', 'PROPN'),
#   ('Brosnan', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('narre', 'VERB'),
#   ("l'", 'DET'),
#   ('histoire', 'NFS'),
#   ("d'", 'PREP'),
#   ('un', 'DINTMS'),
#   ('nègre', 'NMS'),
#   ('engagé', 'VPPMS'),
#   ('pour', 'PREP'),
#   ('terminer', 'VERB'),
#   ('les', 'DET'),
#   ('mémoires', 'NMP'),
#   ("d'", 'PREP'),
#   ('un', 'DINTMS'),
#   ('ancien', 'ADJMS'),
#   ('Premier', 'ADJMS'),
#   ('ministre', 'NMS'),
#   ('britannique', 'ADJMS'),
#   ('mais', 'COCO'),
#   ('dont', 'PREL'),
#   ('la', 'DETFS'),
#   ('mission', 'NFS'),
#   ('se', 'PREF'),
#   ('révèle', 'VERB'),
#   ('périlleuse', 'ADJFS'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('jeune', 'ADJFS'),
#   ('Marian', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('contraction', 'NFS'),
#   ('de', 'PREP'),
#   ('Mary', 'PROPN'),
#   ('Anne', 'XFAMIL'),
#   (')', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('se', 'PREF'),
#   ('révèle', 'VERB'),
#   ("d'", 'PREP'),
#   ('un', 'DINTMS'),
#   ('caractère', 'NMS'),
#   ('obstiné', 'ADJMS'),
#   ('et', 'COCO'),
#   ('ombrageux', 'ADJ'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('a', 'AUX'),
#   ('fait', 'VPPMS'),
#   ('partie', 'NFS'),
#   ('de', 'PREP'),
#   ('groupes', 'NMP'),
#   ('musicaux', 'ADJMP'),
#   ('comme', 'PREP'),
#   ('Los', 'MOTINC'),
#   ('Abuelos', 'MOTINC'),
#   ('de', 'MOTINC'),
#   ('la', 'MOTINC'),
#   ('Nada', 'MOTINC'),
#   ('et', 'COCO'),
#   ('Los', 'MOTINC'),
#   ('Rodríguez', 'MOTINC'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('conventions', 'NFP'),
#   ('signées', 'VPPFP'),
#   ('entre', 'PREP'),
#   ("l'", 'DET'),
#   ('UFE', 'PROPN'),
#   ('et', 'COCO'),
#   ('les', 'DET'),
#   ('universités', 'NFP'),
#   ('françaises', 'ADJFP'),
#   ('partenaires', 'ADJFP'),
#   ('garantissent', 'VERB'),
#   ('que', 'COSUB'),
#   ("l'", 'DET'),
#   ('université', 'NFS'),
#   ('est', 'AUX'),
#   ('qualifiée', 'VPPFS'),
#   ('selon', 'PREP'),
#   ('les', 'DET'),
#   ('critères', 'NMP'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('Union', 'NFS'),
#   ('européenne', 'ADJFS'),
#   ('.', 'YPFOR')],
#  [('Adam', 'PROPN'),
#   ('est', 'AUX'),
#   ('le', 'DETMS'),
#   ('berceau', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('tribu', 'NFS'),
#   ('Al', 'PROPN'),
#   ('Bu', 'XFAMIL'),
#   ('Said', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('dont', 'PREL'),
#   ('est', 'AUX'),
#   ('issu', 'ADJMS'),
#   ("l'", 'DET'),
#   ('actuel', 'ADJMS'),
#   ('sultan', 'NMS'),
#   ('Qabus', 'PROPN'),
#   ('ibn', 'XFAMIL'),
#   ('Said', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('album', 'NMS'),
#   ('de', 'PREP'),
#   ('photos', 'NFP'),
#   ('de', 'PREP'),
#   ('police', 'NFS'),
#   ('exposé', 'VPPMS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('musée', 'NMS'),
#   ("d'", 'PREP'),
#   ('Histoire', 'NFS'),
#   ('politique', 'ADJFS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Russie', 'PROPN'),
#   ('de', 'PREP'),
#   ('Saint-Pétersbourg', 'PROPN'),
#   ('révèle', 'VERB'),
#   ('le', 'DETMS'),
#   ('visage', 'NMS'),
#   ('de', 'PREP'),
#   ('Raspoutine', 'PROPN'),
#   ('défoncé', 'VPPMS'),
#   ('par', 'PREP'),
#   ('des', 'DET'),
#   ('coups', 'NMP'),
#   ('et', 'COCO'),
#   ('son', 'DET'),
#   ('corps', 'NMS'),
#   ('avec', 'PREP'),
#   ('quatre', 'CHIF'),
#   ('points', 'NMP'),
#   ("d'", 'PREP'),
#   ('impacts', 'NMP'),
#   ('de', 'PREP'),
#   ('balles', 'NFP'),
#   ('qui', 'PREL'),
#   ('ont', 'AUX'),
#   ('traversé', 'VPPMS'),
#   ('le', 'DETMS'),
#   ('cœur', 'NMS'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('cou', 'NMS'),
#   ('et', 'COCO'),
#   ('le', 'DETMS'),
#   ('cerveau', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('moments', 'NMP'),
#   ('les', 'DET'),
#   ('plus', 'ADV'),
#   ('appréciés', 'VPPMP'),
#   ('sont', 'AUX'),
#   ("l'", 'DET'),
#   ('apparition', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('premières', 'ADJFP'),
#   ('fleurs', 'NFP'),
#   ('que', 'PREL'),
#   ('guettent', 'VERB'),
#   ('les', 'DET'),
#   ('photographes', 'NMP'),
#   ('et', 'COCO'),
#   ('la', 'DETFS'),
#   ('période', 'NFS'),
#   ('de', 'PREP'),
#   ('pic', 'NMS'),
#   ('de', 'PREP'),
#   ('floraison', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('est', 'AUX'),
#   ('fêté', 'VPPMS'),
#   ('le', 'DETMS'),
#   ('22', 'CHIF'),
#   ('mai', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Une', 'DINTFS'),
#   ('série', 'NFS'),
#   ('placée', 'VPPFS'),
#   ('sur', 'PREP'),
#   ('une', 'DINTFS'),
#   ('orbite', 'NFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('matin', 'NMS'),
#   ('(', 'PUNCT'),
#   ('Morning', 'PROPN'),
#   ('Orbit', 'XFAMIL'),
#   ('ou', 'COCO'),
#   ('M', 'PROPN'),
#   (')', 'PUNCT'),
#   ('dédiée', 'VPPFS'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('étude', 'NFS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('météorologie', 'NFS'),
#   (',', 'PUNCT'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('atmosphère', 'NFS'),
#   (',', 'PUNCT'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('océan', 'NMS'),
#   ('et', 'COCO'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('glaces', 'NFP'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('a', 'AUX'),
#   ('eu', 'VPPMS'),
#   ('alors', 'ADV'),
#   ('comme', 'PREP'),
#   ('élèves', 'NMP'),
#   (':', 'PUNCT'),
#   ('les', 'DET'),
#   ('israéliens', 'NMP'),
#   ('Galit', 'PROPN'),
#   ('Chait', 'XFAMIL'),
#   ('/', 'SYM'),
#   ('Sergei', 'PROPN'),
#   ('Sakhnovski', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('les', 'DET'),
#   ('britanniques', 'NMP'),
#   ('Sinead', 'PROPN'),
#   ('Kerr', 'XFAMIL'),
#   ('/', 'SYM'),
#   ('John', 'PROPN'),
#   ('Kerr', 'XFAMIL'),
#   ('...', 'PUNCT')],
#  [('Alain', 'PROPN'),
#   ('Souchon', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('né', 'VPPMS'),
#   ('Alain', 'PROPN'),
#   ('Kienast', 'XFAMIL'),
#   ('le', 'DETMS'),
#   ('27', 'CHIF'),
#   ('mai', 'NMS'),
#   ('1944', 'CHIF'),
#   ('à', 'PREP'),
#   ('Casablanca', 'PROPN'),
#   (',', 'PUNCT'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Maroc', 'PROPN'),
#   (',', 'PUNCT'),
#   ('est', 'AUX'),
#   ('un', 'DINTMS'),
#   ('auteur-compositeur-interprète', 'NMS'),
#   ('et', 'COCO'),
#   ('acteur', 'NMS'),
#   ('français', 'ADJ'),
#   ('(', 'PUNCT'),
#   ('avec', 'PREP'),
#   ('une', 'DINTFS'),
#   ('double', 'ADJFS'),
#   ('nationalité', 'NFS'),
#   ('suisse', 'ADJFS'),
#   (')', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Dans', 'PREP'),
#   ("l'", 'DET'),
#   ('étape', 'NFS'),
#   ('de', 'PREP'),
#   ('jeudi', 'NMS'),
#   ('(', 'PUNCT'),
#   ('Tourmalet', 'PROPN'),
#   (')', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('qui', 'PREL'),
#   ('est', 'AUX'),
#   ('très', 'ADV'),
#   ('dure', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('faut', 'VERB'),
#   ("s'", 'PREF'),
#   ('attendre', 'VERB'),
#   ('à', 'PREP'),
#   ('de', 'DET'),
#   ('très', 'ADV'),
#   ('gros', 'ADJ'),
#   ('écarts', 'NMP'),
#   (',', 'PUNCT'),
#   ('supérieurs', 'ADJMP'),
#   ('à', 'PREP'),
#   ('ceux', 'PDEMMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('contre-la-montre', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('cuisinières', 'NFP'),
#   ('apparaissent', 'VERB'),
#   ('début', 'NMS'),
#   ('XIXe', 'ADJMS'),
#   ('siècle', 'NMS'),
#   ('avec', 'PREP'),
#   ('les', 'DET'),
#   ('gaz', 'NMP'),
#   ('manufacturés', 'ADJMP'),
#   ('.', 'YPFOR')],
#  [('Vraiment', 'ADV'),
#   ('très', 'ADV'),
#   ('bon', 'ADJMS'),
#   ('resto', 'NMS'),
#   ('avec', 'PREP'),
#   ('un', 'DINTMS'),
#   ('accueil', 'NMS'),
#   ('aussi', 'ADV'),
#   ('chaleureux', 'ADJ'),
#   ("qu'", 'COSUB'),
#   ('enthousiaste', 'ADJMS'),
#   ('...', 'PUNCT'),
#   ('Les', 'DET'),
#   ('plats', 'NMP'),
#   ('sont', 'AUX'),
#   ('copieux', 'ADJ'),
#   ('et', 'COCO'),
#   ('cuisinés', 'VPPMP'),
#   ('avec', 'PREP'),
#   ('de', 'DET'),
#   ('bons', 'ADJMP'),
#   ('produits', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('autorisa', 'VERB'),
#   ("l'", 'DET'),
#   ('installation', 'NFS'),
#   ('de', 'PREP'),
#   ('pompes', 'NFP'),
#   ('à', 'PREP'),
#   ('feu', 'NMS'),
#   ('pour', 'PREP'),
#   ('approvisionner', 'VERB'),
#   ('Paris', 'PROPN'),
#   ('en', 'PREP'),
#   ('eau', 'NFS'),
#   ('de', 'PREP'),
#   ('manière', 'NFS'),
#   ('régulière', 'ADJFS'),
#   ('.', 'YPFOR')],
#  [('Cette', 'PDEMFS'),
#   ('force', 'NFS'),
#   ('résulte', 'VERB'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('faible', 'ADJFS'),
#   ('poussée', 'NFS'),
#   ('exercée', 'VPPFS'),
#   ('par', 'PREP'),
#   ('la', 'DETFS'),
#   ('restitution', 'NFS'),
#   ('sous', 'PREP'),
#   ('forme', 'NFS'),
#   ('de', 'PREP'),
#   ('rayonnement', 'NMS'),
#   ('infrarouge', 'ADJMS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('énergie', 'NFS'),
#   ('solaire', 'ADJFS'),
#   ('absorbée', 'VPPFS'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ('est', 'AUX'),
#   ('traditionnellement', 'ADV'),
#   ('divisée', 'VPPFS'),
#   ('en', 'PREP'),
#   ('deux', 'CHIF'),
#   ('parties', 'NFP'),
#   (':', 'PUNCT'),
#   ('la', 'DETFS'),
#   ('zone', 'NFS'),
#   ('de', 'PREP'),
#   ('Sorgenfrei-Tornquist', 'PROPN'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('nord-ouest', 'NMS'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('la', 'DETFS'),
#   ('zone', 'NFS'),
#   ('de', 'PREP'),
#   ('Teisseyre-Tornquist', 'PROPN'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('sud-est', 'NMS'),
#   (',', 'PUNCT'),
#   ('la', 'DETFS'),
#   ('jonction', 'NFS'),
#   ("s'", 'PREF'),
#   ('effectuant', 'VERB'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('niveau', 'NMS'),
#   ('de', 'PREP'),
#   ('Bornholm', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Thionville', 'PROPN'),
#   ('et', 'COCO'),
#   ('Congerville', 'PROPN'),
#   ('furent', 'AUX'),
#   ('créée', 'VPPFS'),
#   ('en', 'PREP'),
#   ('1793', 'CHIF'),
#   ('avec', 'PREP'),
#   ('leur', 'DET'),
#   ('nom', 'NMS'),
#   ('actuel', 'ADJMS'),
#   ('et', 'COCO'),
#   ('fusionnèrent', 'VERB'),
#   ('en', 'PREP'),
#   ('1973', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Une', 'DINTFS'),
#   ('autre', 'ADJFS'),
#   ('fois', 'NFS'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('va', 'VERB'),
#   ('organiser', 'VERB'),
#   ('une', 'DINTFS'),
#   ('farce', 'NFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('capitaine', 'NMS'),
#   ('Sig', 'PROPN'),
#   ('Hansen', 'XFAMIL'),
#   ('en', 'PREP'),
#   ('faisant', 'AUX'),
#   ('jeter', 'VERB'),
#   ('un', 'DINTMS'),
#   ('mannequin', 'NMS'),
#   ('déguisé', 'VPPMS'),
#   ('en', 'PREP'),
#   ('matelot', 'NMS'),
#   ('depuis', 'PREP'),
#   ('le', 'DETMS'),
#   ('toit', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('timonerie', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('lazy', 'X'),
#   ('bed', 'MOTINC'),
#   ('(', 'PUNCT'),
#   ('littéralement', 'ADV'),
#   (':', 'PUNCT'),
#   ('«', 'PUNCT'),
#   ('plate-bande', 'NFS'),
#   ('de', 'PREP'),
#   ('paresseux', 'NMS'),
#   ('»', 'PUNCT'),
#   (')', 'PUNCT'),
#   ('est', 'AUX'),
#   ('une', 'DINTFS'),
#   ('technique', 'NFS'),
#   ('de', 'PREP'),
#   ('travail', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('sol', 'NMS'),
#   ('autrefois', 'ADV'),
#   ('pratiquée', 'VPPFS'),
#   ('dans', 'PREP'),
#   ('certaines', 'DET'),
#   ('régions', 'NFP'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('Îles', 'NFP'),
#   ('britanniques', 'ADJFP'),
#   ('.', 'YPFOR')],
#  [('Tarzan', 'PROPN'),
#   (',', 'PUNCT'),
#   ("l'", 'DET'),
#   ('homme', 'NMS'),
#   ('singe', 'NMS'),
#   (',', 'PUNCT'),
#   ('règne', 'VERB'),
#   ('en', 'PREP'),
#   ('maître', 'NMS'),
#   ('sur', 'PREP'),
#   ('son', 'DET'),
#   ('domaine', 'NMS'),
#   (',', 'PUNCT'),
#   ('la', 'DETFS'),
#   ('jungle', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('solde', 'NMS'),
#   ('naturel', 'ADJMS'),
#   ('annuel', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('qui', 'PREL'),
#   ('est', 'AUX'),
#   ('la', 'DETFS'),
#   ('différence', 'NFS'),
#   ('entre', 'PREP'),
#   ('le', 'DETMS'),
#   ('nombre', 'NMS'),
#   ('de', 'PREP'),
#   ('naissances', 'NFP'),
#   ('et', 'COCO'),
#   ('le', 'DETMS'),
#   ('nombre', 'NMS'),
#   ('de', 'PREP'),
#   ('décès', 'NOUN'),
#   ('enregistrés', 'VPPMP'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('cours', 'NMS'),
#   ("d'", 'PREP'),
#   ('une', 'DINTFS'),
#   ('même', 'ADJFS'),
#   ('année', 'NFS'),
#   (',', 'PUNCT'),
#   ('connaît', 'VERB'),
#   ('une', 'DINTFS'),
#   ('forte', 'ADJFS'),
#   ('augmentation', 'NFS'),
#   (',', 'PUNCT'),
#   ('puisque', 'COSUB'),
#   ('la', 'DETFS'),
#   ('variation', 'NFS'),
#   ('annuelle', 'ADJFS'),
#   ('due', 'VPPFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('solde', 'NMS'),
#   ('naturel', 'ADJMS'),
#   ('passe', 'VERB'),
#   ('de', 'PREP'),
#   ('-1', 'CHIF'),
#   ('à', 'PREP'),
#   ('-0,8', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('ne', 'ADV'),
#   ('sera', 'AUX'),
#   ('présent', 'ADJMS'),
#   ('que', 'ADV'),
#   ('durant', 'PREP'),
#   ('les', 'DET'),
#   ('10', 'CHIF'),
#   ('premières', 'ADJFP'),
#   ('parties', 'NFP'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('capteurs', 'NMP'),
#   ('solaires', 'ADJMP'),
#   ('sous', 'PREP'),
#   ('vide', 'NMS'),
#   ('de', 'PREP'),
#   ('Viessmann', 'PROPN'),
#   ('offrent', 'VERB'),
#   ('un', 'DINTMS'),
#   ('rendement', 'NMS'),
#   ('optique', 'ADJMS'),
#   ('maximal', 'ADJMS'),
#   ('(', 'PUNCT'),
#   ('de', 'PREP'),
#   ('près', 'ADV'),
#   ('80', 'CHIF'),
#   ('%', 'SYM'),
#   (')', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('verra', 'VERB'),
#   ('le', 'DETMS'),
#   ('puits', 'NMS'),
#   ('le', 'DETMS'),
#   ('plus', 'ADV'),
#   ('profond', 'ADJMS'),
#   ('de', 'PREP'),
#   ('France', 'PROPN'),
#   ('porter', 'VERB'),
#   ('son', 'DET'),
#   ('nom', 'NMS'),
#   (':', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Historiquement', 'ADV'),
#   ('rattachée', 'VPPFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('diocèse', 'NMS'),
#   ('de', 'PREP'),
#   ('Saint-Omer', 'PROPN'),
#   (',', 'PUNCT'),
#   ('on', 'PINDMS'),
#   ('trouve', 'VERB'),
#   ('trace', 'NFS'),
#   ('écrite', 'VPPFS'),
#   ('de', 'PREP'),
#   ('"', 'PUNCT'),
#   ('Sanctus', 'PROPN'),
#   ('Georgius', 'XFAMIL'),
#   ('"', 'PUNCT'),
#   ('en', 'PREP'),
#   ('1178', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('premier', 'ADJMS'),
#   ('recensement', 'NMS'),
#   ('exhaustif', 'ADJMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('commune', 'NFS'),
#   ('entrant', 'VERB'),
#   ('dans', 'PREP'),
#   ('le', 'DETMS'),
#   ('cadre', 'NMS'),
#   ('de', 'PREP'),
#   ('ce', 'PDEMMS'),
#   ('nouveau', 'ADJMS'),
#   ('dispositif', 'NMS'),
#   ('a', 'AUX'),
#   ('eu', 'VPPMS'),
#   ('lieu', 'NMS'),
#   ('en', 'PREP'),
#   ('2004', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Pour', 'PREP'),
#   ('sa', 'DET'),
#   ('saison', 'NFS'),
#   ('de', 'PREP'),
#   ('rookie', 'NMS'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('entre', 'VERB'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('cours', 'NMS'),
#   ('de', 'PREP'),
#   ('deux', 'CHIF'),
#   ('matchs', 'NMP'),
#   ('mais', 'COCO'),
#   ('ne', 'ADV'),
#   ('réussi', 'VPPMS'),
#   ("qu'", 'ADV'),
#   ('une', 'DINTFS'),
#   ('seule', 'ADJFS'),
#   ('passe', 'NFS'),
#   ('sur', 'PREP'),
#   ('six', 'CHIF'),
#   ('tentées', 'VPPFP'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('culte', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('roi', 'NMS'),
#   ('est', 'AUX'),
#   ('un', 'DINTMS'),
#   ('élément', 'NMS'),
#   ('essentiel', 'ADJMS'),
#   ('dans', 'PREP'),
#   ('la', 'DETFS'),
#   ('mobilisation', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('masses', 'NFP'),
#   ('marocaines', 'ADJFP'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('canton', 'NMS'),
#   ('de', 'PREP'),
#   ('Mortagne-sur-Sèvre', 'PROPN'),
#   ('est', 'AUX'),
#   ('une', 'DINTFS'),
#   ('division', 'NFS'),
#   ('administrative', 'ADJFS'),
#   ('française', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('située', 'VPPFS'),
#   ('dans', 'PREP'),
#   ('le', 'DETMS'),
#   ('département', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Vendée', 'PROPN'),
#   ('et', 'COCO'),
#   ('la', 'DETFS'),
#   ('région', 'NFS'),
#   ('Pays', 'NOUN'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Loire', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('détroit', 'NMS'),
#   ('est', 'AUX'),
#   ('traversé', 'VPPMS'),
#   ('par', 'PREP'),
#   ('deux', 'CHIF'),
#   ('ponts', 'NMP'),
#   ('routiers', 'ADJMP'),
#   (':', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('Carquinez', 'PROPN'),
#   ('Bridge', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('sur', 'PREP'),
#   ('lequel', 'PRELMS'),
#   ('passe', 'VERB'),
#   ("l'", 'DET'),
#   ('Interstate', 'PROPN'),
#   ('80', 'CHIF'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('le', 'DETMS'),
#   ('Benicia', 'PROPN'),
#   ('-', 'PUNCT'),
#   ('Martinez', 'XFAMIL'),
#   ('Bridge', 'XFAMIL'),
#   ('emprunté', 'VPPMS'),
#   ('par', 'PREP'),
#   ("l'", 'DET'),
#   ('Interstate', 'PROPN'),
#   ('680', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('gardien', 'NMS'),
#   ('algérien', 'ADJMS'),
#   ('a', 'AUX'),
#   ('lui', 'PPOBJMS'),
#   ('aussi', 'ADV'),
#   ('laissé', 'VPPMS'),
#   ('filer', 'VERB'),
#   ('le', 'DETMS'),
#   ('ballon', 'NMS'),
#   ('dans', 'PREP'),
#   ('ses', 'DET'),
#   ('buts', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('places', 'NFP'),
#   ("d'", 'PREP'),
#   ('accueil', 'NMS'),
#   ("s'", 'PREF'),
#   ('adressent', 'VERB'),
#   ('en', 'PREP'),
#   ('priorité', 'NFS'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('parents', 'NMP'),
#   ('qui', 'PREL'),
#   ('travaillent', 'VERB'),
#   ('et', 'COCO'),
#   ("n'", 'ADV'),
#   ('ont', 'VERB'),
#   ('pas', 'ADV'),
#   ('de', 'DET'),
#   ('possibilité', 'NFS'),
#   ('de', 'PREP'),
#   ('garde', 'NFS'),
#   ('pour', 'PREP'),
#   ('leur', 'DET'),
#   ('enfant', 'NOUN'),
#   ('.', 'YPFOR')],
#  [('Avec', 'PREP'),
#   ("l'", 'DET'),
#   ('élargissement', 'NMS'),
#   ('de', 'PREP'),
#   ('ses', 'DET'),
#   ('activités', 'NFP'),
#   (',', 'PUNCT'),
#   ("l'", 'DET'),
#   ('orchestre', 'NMS'),
#   ('décide', 'VERB'),
#   ("d'", 'PREP'),
#   ('abandonner', 'VERB'),
#   ('ce', 'PDEMMS'),
#   ('système', 'NMS'),
#   ('en', 'PREP'),
#   ('1933', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('24e', 'ADJMS'),
#   ('RIC', 'PROPN'),
#   (',', 'PUNCT'),
#   ('créé', 'VPPMS'),
#   ('par', 'PREP'),
#   ('décret', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('16', 'CHIF'),
#   ('décembre', 'NMS'),
#   ('1902', 'CHIF'),
#   ('a', 'AUX'),
#   ('été', 'AUX'),
#   ('mis', 'VERB'),
#   ('sur', 'PREP'),
#   ('pied', 'NMS'),
#   ('à', 'PREP'),
#   ('Perpignan', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('On', 'PINDMS'),
#   ('notera', 'VERB'),
#   ('bien', 'ADV'),
#   ('évidemment', 'ADV'),
#   ('le', 'DETMS'),
#   ('Marsupilami', 'PROPN'),
#   (',', 'PUNCT'),
#   ('qui', 'PREL'),
#   ('restera', 'VERB'),
#   ('en', 'PREP'),
#   ('leur', 'DET'),
#   ('compagnie', 'NFS'),
#   ('durant', 'PREP'),
#   ('toute', 'ADJFS'),
#   ('cette', 'PDEMFS'),
#   ('période', 'NFS'),
#   (',', 'PUNCT'),
#   ('mais', 'COCO'),
#   ('aussi', 'ADV'),
#   ('la', 'DETFS'),
#   ('jeune', 'ADJFS'),
#   ('journaliste', 'NFS'),
#   ('Seccotine', 'PROPN'),
#   (',', 'PUNCT'),
#   ('ainsi', 'ADV'),
#   ('que', 'COSUB'),
#   ('le', 'DETMS'),
#   ('comte', 'NMS'),
#   ('de', 'PREP'),
#   ('Champignac', 'PROPN'),
#   (',', 'PUNCT'),
#   ('qui', 'PREL'),
#   ('restera', 'VERB'),
#   ('un', 'DINTMS'),
#   ('peu', 'ADV'),
#   ('le', 'DETMS'),
#   ('grand-père', 'NMS'),
#   ('de', 'PREP'),
#   ('cœur', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('deux', 'CHIF'),
#   ('héros', 'NMP'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('junk-food', 'NFS'),
#   ('rend', 'VERB'),
#   ('aussi', 'ADV'),
#   ('accro', 'ADJMS'),
#   ('que', 'COSUB'),
#   ('les', 'DET'),
#   ('drogues', 'NFP'),
#   ('dures', 'ADJFP'),
#   ('!', 'PUNCT')],
#  [('Les', 'DET'),
#   ('effets', 'NMP'),
#   ('cliniques', 'ADJMP'),
#   ('sont', 'AUX'),
#   ('possibles', 'ADJMP'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('bout', 'NMS'),
#   ('de', 'PREP'),
#   ('quelques', 'DET'),
#   ('semaines', 'NFP'),
#   ('de', 'PREP'),
#   ('traitement', 'NMS'),
#   (',', 'PUNCT'),
#   ('mais', 'COCO'),
#   ('inconstants', 'ADJMP'),
#   ('.', 'YPFOR')],
#  [('Elles', 'PPER3FP'),
#   ('furent', 'AUX'),
#   ('victimes', 'ADJFP'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Révolution', 'NFS'),
#   ('française', 'ADJFS'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('gouvernement', 'NMS'),
#   ('Papadímos', 'PROPN'),
#   ('succède', 'VERB'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('gouvernement', 'NMS'),
#   ('Geórgios', 'PROPN'),
#   ('Papandréou', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('dont', 'PREL'),
#   ('douze', 'CHIF'),
#   ('membres', 'NMP'),
#   ('sont', 'AUX'),
#   ('reconduits', 'VPPMP'),
#   (',', 'PUNCT'),
#   ('notamment', 'ADV'),
#   ('le', 'DETMS'),
#   ('ministre', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('Finances', 'NFP'),
#   (',', 'PUNCT'),
#   ('Evángelos', 'PROPN'),
#   ('Venizélos', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('la', 'DETFS'),
#   ('ministre', 'NFS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('Éducation', 'NFS'),
#   (',', 'PUNCT'),
#   ('Ánna', 'PROPN'),
#   ('Diamantopoúlou', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('ministre', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Santé', 'NFS'),
#   (',', 'PUNCT'),
#   ('Andréas', 'PROPN'),
#   ('Lovérdos', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('le', 'DETMS'),
#   ('ministre', 'NMS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('Environnement', 'NMS'),
#   (',', 'PUNCT'),
#   ('Giórgos', 'PROPN'),
#   ('Papakonstantínou', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('éditeur-en-chef', 'NMS'),
#   ('est', 'AUX'),
#   ('Corey', 'PROPN'),
#   ('S.', 'XFAMIL'),
#   ('Powell', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [('Nous', 'PREFP'),
#   ('sommes', 'AUX'),
#   ('allés', 'VPPMP'),
#   ('samedi', 'NMS'),
#   ('soir', 'NMS'),
#   ('(', 'PUNCT'),
#   ('vers', 'PREP'),
#   ('23h', 'NFP'),
#   (')', 'PUNCT'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('HD', 'NMS'),
#   ('de', 'PREP'),
#   ('Saint', 'PROPN'),
#   ('Michel', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [('Par', 'PREP'),
#   ('la', 'DETFS'),
#   ('suite', 'NFS'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('château', 'NMS'),
#   ('fut', 'AUX'),
#   ('démantelé', 'VPPMS'),
#   ('durant', 'PREP'),
#   ('la', 'DETFS'),
#   ('Guerre', 'NFS'),
#   ('de', 'PREP'),
#   ('Trente', 'CHIF'),
#   ('Ans', 'NMP'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('ferté-imbault', 'PROPN'),
#   ('en', 'PREP'),
#   ('Sologne', 'PROPN'),
#   ('vous', 'PREFP'),
#   ('propose', 'VERB'),
#   ('un', 'DINTMS'),
#   ('choix', 'NMS'),
#   ('d', 'PREP'),
#   ('activités', 'NFP'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ('bonnes', 'ADJFP'),
#   ('adresses', 'NFP'),
#   (',', 'PUNCT'),
#   ('parmi', 'PREP'),
#   ('de', 'DET'),
#   ('nombreuses', 'ADJFP'),
#   ('richesses', 'NFP'),
#   ('locales', 'ADJFP'),
#   (',', 'PUNCT'),
#   ('pour', 'PREP'),
#   ('prolonger', 'VERB'),
#   ('agréablement', 'ADV'),
#   ('votre', 'DET'),
#   ('visite', 'NFS'),
#   ('en', 'PREP'),
#   ('Sologne', 'PROPN'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('enquête', 'NFS'),
#   (',', 'PUNCT'),
#   ('menée', 'VPPFS'),
#   ('par', 'PREP'),
#   ('une', 'DINTFS'),
#   ('équipe', 'NFS'),
#   ('de', 'PREP'),
#   ('chercheurs', 'NMP'),
#   ('conduite', 'VPPFS'),
#   ('par', 'PREP'),
#   ('le', 'DETMS'),
#   ('politologue', 'NMS'),
#   ('Gilles', 'PROPN'),
#   ('Kepel', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('montre', 'VERB'),
#   ("qu'", 'COSUB'),
#   ('il', 'PPER3MS'),
#   ("n'", 'ADV'),
#   ('en', 'PPOBJMS'),
#   ('est', 'VERB'),
#   ('rien', 'PRON'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('est', 'AUX'),
#   ('le', 'DETMS'),
#   ('fils', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Hall', 'PROPN'),
#   ('of', 'PREP'),
#   ('Famer', 'XFAMIL'),
#   ('Ricky', 'XFAMIL'),
#   ('The', 'XFAMIL'),
#   ('Dragon', 'XFAMIL'),
#   ('Steamboat', 'PROPN'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('a', 'AUX'),
#   ('été', 'AUX'),
#   ('également', 'ADV'),
#   ('entrainé', 'VPPMS'),
#   ('par', 'PREP'),
#   ('ce', 'PDEMMS'),
#   ('dernier', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('Tous', 'ADJMP'),
#   ('les', 'DET'),
#   ('trains', 'NMP'),
#   ('locaux', 'ADJMP'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('ligne', 'NFS'),
#   ('Nara', 'PROPN'),
#   ("s'", 'PREF'),
#   ('arrêtent', 'VERB'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('gare', 'NFS'),
#   ("d'", 'PREP'),
#   ('Inari', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('On', 'PINDMS'),
#   ('en', 'PPOBJMS'),
#   ('avait', 'AUX'),
#   ('vue', 'VPPFS'),
#   ('une', 'DINTFS'),
#   ('dizaine', 'NFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('premier', 'ADJMS'),
#   ('contrôle', 'NMS'),
#   ('mais', 'COCO'),
#   ('pas', 'ADV'),
#   ('celle', 'PDEMFS'),
#   ('là', 'PART'),
#   ('.', 'YPFOR')],
#  [('Equipiers', 'NMP'),
#   ('et', 'COCO'),
#   ('adversaires', 'NMP'),
#   ('sont', 'AUX'),
#   ('sur', 'PREP'),
#   ('la', 'DETFS'),
#   ('même', 'ADJFS'),
#   ('longueur', 'NFS'),
#   ("d'", 'PREP'),
#   ('ondes', 'NFP'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ('y', 'PPOBJFS'),
#   ('incarnera', 'VERB'),
#   ('la', 'DETFS'),
#   ('Poussette', 'PROPN'),
#   ('de', 'PREP'),
#   ('Manon', 'PROPN'),
#   ('peu', 'ADV'),
#   ('de', 'PREP'),
#   ('temps', 'NOUN'),
#   ('après', 'ADV'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ('fonce', 'VERB'),
#   ('et', 'COCO'),
#   ("c'", 'PDEMMS'),
#   ('est', 'AUX'),
#   ('cette', 'PDEMFS'),
#   ('audace', 'NFS'),
#   ('qui', 'PREL'),
#   ('est', 'AUX'),
#   ('récompensée', 'VPPFS'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('Andalouses', 'PROPN'),
#   ('est', 'AUX'),
#   ('le', 'DETMS'),
#   ('nom', 'NMS'),
#   ("d'", 'PREP'),
#   ('une', 'DINTFS'),
#   ('station', 'NFS'),
#   ('balnéaire', 'ADJFS'),
#   ('algérienne', 'ADJFS'),
#   ('à', 'PREP'),
#   ('23', 'CHIF'),
#   ('km', 'NMP'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('ouest', 'NMS'),
#   ("d'", 'PREP'),
#   ('Oran', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('président', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('club', 'NMS'),
#   (',', 'PUNCT'),
#   ('Angel', 'PROPN'),
#   ('Torres', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('a', 'AUX'),
#   ('déclaré', 'VPPMS'),
#   ("qu'", 'COSUB'),
#   ('il', 'PPER3MS'),
#   ('espérait', 'VERB'),
#   ('que', 'COSUB'),
#   ('le', 'DETMS'),
#   ('contrat', 'NMS'),
#   ('"', 'PUNCT'),
#   ('pousse', 'VERB'),
#   ('Getafe', 'PROPN'),
#   ("jusqu'", 'PREP'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('sommets', 'NMP'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('compétition', 'NFS'),
#   ('nationale', 'ADJFS'),
#   ('et', 'COCO'),
#   ('européenne', 'ADJFS'),
#   ('"', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('De', 'PREP'),
#   ('manière', 'NFS'),
#   ('moins', 'ADV'),
#   ('formelle', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('deux', 'CHIF'),
#   ('figures', 'NFP'),
#   ('sont', 'AUX'),
#   ('congruentes', 'ADJFP'),
#   ('si', 'COSUB'),
#   ('elles', 'PPER3FP'),
#   ('ont', 'VERB'),
#   ('la', 'DETFS'),
#   ('même', 'ADJFS'),
#   ('forme', 'NFS'),
#   ('et', 'COCO'),
#   ('la', 'DETFS'),
#   ('même', 'ADJFS'),
#   ('taille', 'NFS'),
#   (',', 'PUNCT'),
#   ('mais', 'COCO'),
#   ('ont', 'VERB'),
#   ('des', 'DET'),
#   ('positions', 'NFP'),
#   ('différentes', 'ADJFP'),
#   ('.', 'YPFOR')],
#  [('Des', 'DET'),
#   ('discours', 'NMP'),
#   ('violents', 'ADJMP'),
#   ('contre', 'PREP'),
#   ('les', 'DET'),
#   ('Juifs', 'NMP'),
#   ('sont', 'AUX'),
#   ('prononcés', 'VPPMP'),
#   ('le', 'DETMS'),
#   ('12', 'CHIF'),
#   ('décembre', 'NMS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Reichsrath', 'PROPN'),
#   ('et', 'COCO'),
#   ('le', 'DETMS'),
#   ('Dr.', 'NMS'),
#   ('Baxa', 'PROPN'),
#   (',', 'PUNCT'),
#   ("l'", 'DET'),
#   ('avocat', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('famille', 'NFS'),
#   ('Hruza', 'PROPN'),
#   (',', 'PUNCT'),
#   ('dans', 'PREP'),
#   ('un', 'DINTMS'),
#   ('discours', 'NMS'),
#   ('devant', 'PREP'),
#   ('la', 'DETFS'),
#   ('Diète', 'PROPN'),
#   ('de', 'PREP'),
#   ('Bohême', 'PROPN'),
#   ('le', 'DETMS'),
#   ('28', 'CHIF'),
#   ('décembre', 'NMS'),
#   ('accuse', 'VERB'),
#   ('le', 'DETMS'),
#   ('gouvernement', 'NMS'),
#   ("d'", 'PREP'),
#   ('impartialité', 'NFS'),
#   ('en', 'PREP'),
#   ('faveur', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('Juifs', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('reste', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('Ryūzōji', 'PROPN'),
#   ('continuait', 'VERB'),
#   ('à', 'PREP'),
#   ('disputer', 'VERB'),
#   ('la', 'DETFS'),
#   ('propriété', 'NFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('domaine', 'NMS'),
#   ('de', 'PREP'),
#   ('temps', 'NOUN'),
#   ('en', 'PREP'),
#   ('temps', 'NOUN'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('menaçait', 'VERB'),
#   ('la', 'DETFS'),
#   ('main-mise', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('Nabeshima', 'PROPN'),
#   ('sur', 'PREP'),
#   ('celui-ci', 'PDEMMS'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('matricule', 'NMS'),
#   ('18', 'CHIF'),
#   ('remporta', 'VERB'),
#   ('six', 'CHIF'),
#   ('titres', 'NMP'),
#   ('en', 'PREP'),
#   ('séries', 'NFP'),
#   ('nationales', 'ADJFP'),
#   (':', 'PUNCT')],
#  [('Il', 'PPER3MS'),
#   ("s'", 'PREF'),
#   ('agit', 'VERB'),
#   ("d'", 'PREP'),
#   ('une', 'DINTFS'),
#   ('action', 'NFS'),
#   ('complémentaire', 'ADJFS'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('dispositions', 'NFP'),
#   ('administratives', 'ADJFP'),
#   ('et', 'COCO'),
#   ('juridiques', 'ADJFP'),
#   ('déjà', 'ADV'),
#   ('prises', 'VPPFP'),
#   ('ou', 'COCO'),
#   ('encours', 'NOUN'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('plus', 'ADV'),
#   ('haut', 'ADJMS'),
#   ('niveau', 'NMS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('État', 'NMS'),
#   ('vue', 'NFS'),
#   ("d'", 'PREP'),
#   ('améliorer', 'VERB'),
#   ('la', 'DETFS'),
#   ('situation', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('veuves', 'NFP'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('cathédrale', 'NFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Christ', 'PROPN'),
#   ('Rédempteur', 'ADJMS'),
#   ('(', 'PUNCT'),
#   ('Cathedral', 'MOTINC'),
#   ('Church', 'MOTINC'),
#   ('of', 'MOTINC'),
#   ('Christ', 'MOTINC'),
#   ('the', 'MOTINC'),
#   ('Redeemer', 'MOTINC'),
#   (')', 'PUNCT'),
#   ('de', 'PREP'),
#   ('Dromore', 'PROPN'),
#   ('est', 'AUX'),
#   ('une', 'DINTFS'),
#   ('cathédrale', 'NFS'),
#   ('anglicane', 'ADJFS'),
#   ('britannique', 'ADJFS'),
#   ('située', 'VPPFS'),
#   ('en', 'PREP'),
#   ('Irlande', 'PROPN'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Nord', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Entre', 'PREP'),
#   ('2004', 'CHIF'),
#   ('et', 'COCO'),
#   ('2006', 'CHIF'),
#   (',', 'PUNCT'),
#   ('elle', 'PPER3FS'),
#   ('a', 'AUX'),
#   ('travaillé', 'VPPMS'),
#   ('comme', 'PREP'),
#   ('journaliste', 'NMS'),
#   (',', 'PUNCT'),
#   ('reporter', 'NMS'),
#   ('et', 'COCO'),
#   ('présentatrice', 'NFS'),
#   ('pour', 'PREP'),
#   ("l'", 'DET'),
#   ('émission', 'NFS'),
#   ('«', 'PUNCT'),
#   ('Absolutt', 'MOTINC'),
#   ('underholdning', 'MOTINC'),
#   ('»', 'PUNCT'),
#   ('diffusée', 'VPPFS'),
#   ('sur', 'PREP'),
#   ('TV', 'NFS'),
#   ('2', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('est', 'AUX'),
#   ("l'", 'DET'),
#   ('auteur', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('premier', 'ADJMS'),
#   ('roman', 'NMS'),
#   ('canadien', 'ADJMS'),
#   ('français', 'ADJ'),
#   ('publié', 'VPPMS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Canada', 'PROPN'),
#   (',', 'PUNCT'),
#   ('intitulé', 'VPPMS'),
#   ("L'", 'DET'),
#   ('influence', 'NFS'),
#   ("d'", 'PREP'),
#   ('un', 'DINTMS'),
#   ('livre', 'NMS'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('extension', 'NFS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('ligne', 'NFS'),
#   ('7', 'CHIF'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('métro', 'NMS'),
#   ('de', 'PREP'),
#   ('New', 'PROPN'),
#   ('York', 'XFAMIL'),
#   ('est', 'AUX'),
#   ('étroitement', 'ADV'),
#   ('liée', 'VPPFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('ré-aménagement', 'NMS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('Hudson', 'PROPN'),
#   ('Yards', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('elle', 'PPER3FS'),
#   ('a', 'VERB'),
#   ('pour', 'PREP'),
#   ('but', 'NMS'),
#   ("d'", 'PREP'),
#   ('étendre', 'VERB'),
#   ("l'", 'DET'),
#   ('IRT', 'MOTINC'),
#   ('Flushing', 'MOTINC'),
#   ('Line', 'MOTINC'),
#   (',', 'PUNCT'),
#   ('vers', 'PREP'),
#   ("l'", 'DET'),
#   ('ouest', 'NMS'),
#   ('à', 'PREP'),
#   ('partir', 'VERB'),
#   ('de', 'PREP'),
#   ('son', 'DET'),
#   ('terminus', 'NMS'),
#   ('actuel', 'ADJMS'),
#   ('à', 'PREP'),
#   ('Times', 'PROPN'),
#   ('Square', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [('Douarnenez', 'PROPN'),
#   ('accueillera', 'VERB'),
#   ('le', 'DETMS'),
#   ('spectacle', 'NMS'),
#   ('de', 'PREP'),
#   ('clôture', 'NFS'),
#   (',', 'PUNCT'),
#   ('pour', 'PREP'),
#   ('trois', 'CHIF'),
#   ('représentations', 'NFP'),
#   ('vendredi', 'NMS'),
#   ('28', 'CHIF'),
#   ('et', 'COCO'),
#   ('samedi', 'NMS'),
#   ('29', 'CHIF'),
#   (',', 'PUNCT'),
#   ('à', 'PREP'),
#   ('20', 'CHIF'),
#   ('h', 'NFP'),
#   ('30', 'CHIF'),
#   (';', 'PUNCT')],
#  [('En', 'PREP'),
#   ('juillet', 'NMS'),
#   ('1941', 'CHIF'),
#   (',', 'PUNCT'),
#   ('une', 'DINTFS'),
#   ('première', 'ADJFS'),
#   ('attaque', 'NFS'),
#   ('aérienne', 'ADJFS'),
#   ("s'", 'PREF'),
#   ('abattit', 'VERB'),
#   ('sur', 'PREP'),
#   ('la', 'DETFS'),
#   ('ville', 'NFS'),
#   (',', 'PUNCT'),
#   ('quatre', 'CHIF'),
#   ('autres', 'PRON'),
#   ('suivirent', 'VERB'),
#   ('.', 'YPFOR')],
#  [("Lorsqu'", 'COSUB'),
#   ('elle', 'PPER3FS'),
#   ("m'", 'PREFS'),
#   ('a', 'AUX'),
#   ('examiné', 'VPPMS'),
#   (',', 'PUNCT'),
#   ('elle', 'PPER3FS'),
#   ('a', 'AUX'),
#   ('appuyé', 'VPPMS'),
#   ('comme', 'PREP'),
#   ('une', 'DINTFS'),
#   ('malade', 'NFS'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('endroit', 'NMS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('opération', 'NFS'),
#   ('et', 'COCO'),
#   ('en', 'PREP'),
#   ('me', 'PREFS'),
#   ('voyant', 'VERB'),
#   ('crier', 'VERB'),
#   (',', 'PUNCT'),
#   ('elle', 'PPER3FS'),
#   ('en', 'PPOBJFS'),
#   ('a', 'AUX'),
#   ('finalement', 'ADV'),
#   ('déduit', 'VPPMS'),
#   ("qu'", 'COSUB'),
#   ('il', 'PPER3MS'),
#   ('fallait', 'VERB'),
#   ('que', 'COSUB'),
#   ('je', 'PPER1S'),
#   ('retourne', 'VERB'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('hopital', 'NMS'),
#   ('.', 'YPFOR')],
#  [('En', 'PREP'),
#   ('2011', 'CHIF'),
#   (',', 'PUNCT'),
#   ('elle', 'PPER3FS'),
#   ('se', 'PREF'),
#   ('blesse', 'VERB'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('entrainement', 'NMS'),
#   ('lors', 'ADV'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('championnats', 'NMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('monde', 'NMS'),
#   ('et', 'COCO'),
#   ("l'", 'PPER3MS'),
#   ('oblige', 'VERB'),
#   ('à', 'PREP'),
#   ('quitter', 'VERB'),
#   ('la', 'DETFS'),
#   ('compétition', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('lui', 'PPOBJMS'),
#   ('restait', 'VERB'),
#   ('à', 'PREP'),
#   ('battre', 'VERB'),
#   ('Pat', 'PROPN'),
#   ('Buchanan', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('relativement', 'ADV'),
#   ('isolé', 'VPPMS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('sein', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('parti', 'NMS'),
#   (',', 'PUNCT'),
#   ('Steve', 'PROPN'),
#   ('Forbes', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('Phillip', 'PROPN'),
#   ('Gramm', 'XFAMIL'),
#   ('(', 'PUNCT'),
#   ('soutenu', 'VPPMS'),
#   ('notamment', 'ADV'),
#   ('par', 'PREP'),
#   ('le', 'DETMS'),
#   ('sénateur', 'NMS'),
#   ('John', 'PROPN'),
#   ('McCain', 'XFAMIL'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('Arizona', 'PROPN'),
#   ('et', 'COCO'),
#   ('la', 'DETFS'),
#   ('sénatrice', 'NFS'),
#   ('Kay', 'PROPN'),
#   ('Bailey', 'XFAMIL'),
#   ('Hutchison', 'XFAMIL'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Texas', 'PROPN'),
#   (')', 'PUNCT'),
#   ('alors', 'ADV'),
#   ('que', 'COSUB'),
#   ('Pete', 'PROPN'),
#   ('Wilson', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('gouverneur', 'NMS'),
#   ('de', 'PREP'),
#   ('Californie', 'PROPN'),
#   ('et', 'COCO'),
#   ('ancien', 'ADJMS'),
#   ('sénateur', 'NMS'),
#   (',', 'PUNCT'),
#   ('soutenu', 'VPPMS'),
#   ('par', 'PREP'),
#   ('la', 'DETFS'),
#   ('branche', 'NFS'),
#   ('modérée', 'ADJFS'),
#   ('et', 'COCO'),
#   ('progressiste', 'ADJFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('parti', 'NMS'),
#   (',', 'PUNCT'),
#   ('se', 'PREF'),
#   ('retirait', 'VERB'),
#   ('rapidement', 'ADV'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('course', 'NFS'),
#   ('.', 'YPFOR')],
#  [('On', 'PINDMS'),
#   ('y', 'PPOBJMS'),
#   ('mange', 'VERB'),
#   ('correctement', 'ADV'),
#   ('à', 'PREP'),
#   ('des', 'DET'),
#   ('prix', 'NMP'),
#   ('raisonnables', 'ADJMP'),
#   ('et', 'COCO'),
#   ('la', 'DETFS'),
#   ('bière', 'NFS'),
#   ('y', 'PPOBJFS'),
#   ('est', 'AUX'),
#   ('bonne', 'ADJFS'),
#   ('.', 'YPFOR')],
#  [('Vers', 'PREP'),
#   ('731', 'CHIF'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('moine', 'NMS'),
#   ('et', 'COCO'),
#   ('chroniqueur', 'NMS'),
#   ('northumbrien', 'ADJMS'),
#   ('Bède', 'PROPN'),
#   ('rédige', 'VERB'),
#   ('son', 'DET'),
#   ('Histoire', 'NFS'),
#   ('ecclésiastique', 'ADJFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('peuple', 'NMS'),
#   ('anglais', 'ADJ'),
#   ('.', 'YPFOR')],
#  [('En', 'PREP'),
#   ('parallèle', 'NFS'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('joue', 'VERB'),
#   ('un', 'DINTMS'),
#   ('rôle', 'NMS'),
#   ('important', 'ADJMS'),
#   ('dans', 'PREP'),
#   ("l'", 'DET'),
#   ('encadrement', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('sélection', 'NFS'),
#   ('nationale', 'ADJFS'),
#   ('togolaise', 'ADJFS'),
#   ('dès', 'PREP'),
#   ('2006', 'CHIF'),
#   (',', 'PUNCT'),
#   ('sous', 'PREP'),
#   ('Otto', 'PROPN'),
#   ('Pfister', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [('On', 'PINDMS'),
#   ('y', 'PPOBJMS'),
#   ('retrouve', 'VERB'),
#   ('les', 'DET'),
#   ('lieux', 'NMP'),
#   ('de', 'PREP'),
#   ('culte', 'NMS'),
#   (',', 'PUNCT'),
#   ('la', 'DETFS'),
#   ('place', 'NFS'),
#   (',', 'PUNCT'),
#   ('la', 'DETFS'),
#   ('mairie', 'NFS'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('les', 'DET'),
#   ('magasins', 'NMP'),
#   ('de', 'PREP'),
#   ('toutes', 'DET'),
#   ('sortes', 'NFP'),
#   ('.', 'YPFOR')],
#  [('Vous', 'PREFP'),
#   ('êtes', 'AUX'),
#   ('abonné', 'VPPMS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('site', 'NMS'),
#   ('?', 'PUNCT')],
#  [('Le', 'DETMS'),
#   ('canton', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('Ulis', 'PROPN'),
#   ('groupe', 'VERB'),
#   ('une', 'DINTFS'),
#   ('commune', 'NFS'),
#   ('et', 'COCO'),
#   ('compte', 'VERB'),
#   ('25 785', 'CHIF'),
#   ('habitants', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Sous', 'PREP'),
#   ('les', 'DET'),
#   ('arcades', 'NFP'),
#   (',', 'PUNCT'),
#   ('dans', 'PREP'),
#   ('les', 'DET'),
#   ('cantons', 'NMP'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('croix', 'NFS'),
#   (',', 'PUNCT'),
#   ('douze', 'CHIF'),
#   ('personnages', 'NMP'),
#   ('debout', 'ADJ'),
#   (',', 'PUNCT'),
#   ('des', 'DET'),
#   ('apôtres', 'NMP'),
#   ('ou', 'COCO'),
#   ('des', 'DET'),
#   ('pères', 'NMP'),
#   ("d'", 'PREP'),
#   ('église', 'NFS'),
#   (',', 'PUNCT'),
#   ('tiennent', 'VERB'),
#   ('de', 'PREP'),
#   ('phylactères', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Un', 'DINTMS'),
#   ('autel', 'NMS'),
#   ('à', 'PREP'),
#   ('Jupiter', 'PROPN'),
#   ('est', 'AUX'),
#   ('érigé', 'VPPMS'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('emplacement', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Temple', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ("l'", 'PPER3MS'),
#   ('oppose', 'VERB'),
#   ('également', 'ADV'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('mouvement', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('coopératives', 'NFP'),
#   (',', 'PUNCT'),
#   ('qui', 'PREL'),
#   ('maintient', 'VERB'),
#   ('le', 'DETMS'),
#   ('salariat', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Pan', 'PROPN'),
#   ('Am', 'XFAMIL'),
#   ('construisit', 'VERB'),
#   ('aussi', 'ADV'),
#   ('Worldport', 'PROPN'),
#   (',', 'PUNCT'),
#   ('un', 'DINTMS'),
#   ('terminal', 'NMS'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('aéroport', 'NMS'),
#   ('JFK', 'PROPN'),
#   ('qui', 'PREL'),
#   ('resta', 'VERB'),
#   ('le', 'DETMS'),
#   ('plus', 'ADV'),
#   ('grand', 'ADJMS'),
#   ('terminal', 'NMS'),
#   ('aérien', 'ADJMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('monde', 'NMS'),
#   ('pendant', 'PREP'),
#   ('de', 'DET'),
#   ('nombreuses', 'ADJFP'),
#   ('années', 'NFP'),
#   (',', 'PUNCT'),
#   ('reconnaissable', 'ADJMS'),
#   ('à', 'PREP'),
#   ('son', 'DET'),
#   ('toit', 'NMS'),
#   ('elliptique', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('suspendu', 'VPPMS'),
#   ('au-dessus', 'ADV'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('terminal', 'NMS'),
#   ('par', 'PREP'),
#   ('32', 'CHIF'),
#   ('jeux', 'NMP'),
#   ('de', 'PREP'),
#   ('poteaux', 'NMP'),
#   ('et', 'COCO'),
#   ('câbles', 'NMP'),
#   ("d'", 'PREP'),
# ...
#   ('D4', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Beauceville', 'PROPN'),
#   ('est', 'AUX'),
#   ('une', 'DINTFS'),
#   ('ville', 'NFS'),
#   ('dans', 'PREP'),
#   ('la', 'DETFS'),
#   ('municipalité', 'NFS'),
#   ('régionale', 'ADJFS'),
#   ('de', 'PREP'),
#   ('comté', 'NMS'),
#   ('de', 'PREP'),
#   ('Robert-Cliche', 'PROPN'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Québec', 'PROPN'),
#   (',', 'PUNCT'),
#   ('située', 'VPPFS'),
#   ('dans', 'PREP'),
#   ('la', 'DETFS'),
#   ('région', 'NFS'),
#   ('administrative', 'ADJFS'),
#   ('de', 'PREP'),
#   ('Chaudière-Appalaches', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('»', 'PUNCT'),
#   ('Stipe', 'PROPN'),
#   ('reconnaît', 'VERB'),
#   ('que', 'COSUB'),
#   ('le', 'DETMS'),
#   ('groupe', 'NMS'),
#   ('sera', 'AUX'),
#   ('différent', 'ADJMS'),
#   ('sans', 'PREP'),
#   ('un', 'PINDMS'),
#   ('de', 'PREP'),
#   ('ses', 'DET'),
#   ('contributeurs', 'NMP'),
#   ('majeurs', 'ADJMP'),
#   (':', 'PUNCT'),
#   ('«', 'PUNCT'),
#   ('Pour', 'PREP'),
#   ('moi', 'PPOBJMP'),
#   (',', 'PUNCT'),
#   ('Mike', 'PROPN'),
#   ('et', 'COCO'),
#   ('Peter', 'PROPN'),
#   (',', 'PUNCT'),
#   ('en', 'PREP'),
#   ('tant', 'ADV'),
#   ('que', 'COSUB'),
#   ('R.E.M.', 'PROPN'),
#   (',', 'PUNCT'),
#   ('sommes', 'AUX'),
#   ('-nous', 'PREFP'),
#   ('encore', 'ADV'),
#   ('R.E.M.', 'PROPN'),
#   ('?', 'PUNCT')],
#  [('Le', 'DETMS'),
#   ('réalisateur', 'NMS'),
#   ('explique', 'VERB'),
#   ('que', 'COSUB'),
#   ('deux', 'CHIF'),
#   ('costumes', 'NMP'),
#   ('ont', 'AUX'),
#   ('été', 'AUX'),
#   ('conçus', 'VPPMP'),
#   ('pour', 'PREP'),
#   ('les', 'DET'),
#   ('besoins', 'NMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('film', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ("n'", 'ADV'),
#   ('a', 'AUX'),
#   ('pas', 'ADV'),
#   ('omis', 'VERB'),
#   ('de', 'PREP'),
#   ('rejeter', 'VERB'),
#   ('dans', 'PREP'),
#   ('le', 'DETMS'),
#   ('point', 'NMS'),
#   ('18', 'CHIF'),
#   ('«', 'PUNCT'),
#   ('toute', 'DET'),
#   ('mesure', 'NFS'),
#   ('visant', 'VERB'),
#   ('à', 'PREP'),
#   ('restreindre', 'VERB'),
#   ('le', 'DETMS'),
#   ('droit', 'NMS'),
#   ('inaliénable', 'ADJMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('Etats', 'PROPN'),
#   ('parties', 'NFP'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('utilisation', 'NFS'),
#   ('pacifique', 'ADJFS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('énergie', 'NFS'),
#   ('nucléaire', 'ADJFS'),
#   ('pour', 'PREP'),
#   ('le', 'DETMS'),
#   ('développement', 'NMS'),
#   ('socioéconomique', 'ADJMS'),
#   ('»', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Dans', 'PREP'),
#   ('le', 'DETMS'),
#   ('domaine', 'NMS'),
#   ('électronique', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('la', 'DETFS'),
#   ('tendance', 'NFS'),
#   ('est', 'AUX'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('miniaturisation', 'NFS'),
#   (';', 'PUNCT')],
#  [('Au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('nom', 'NMS'),
#   ('de', 'PREP'),
#   ('quoi', 'PRON'),
#   ('refuser', 'VERB'),
#   ('telle', 'DET'),
#   ('pratique', 'NFS'),
#   ('et', 'COCO'),
#   ('autoriser', 'VERB'),
#   ('telle', 'DET'),
#   ('autre', 'PRON'),
#   ('?', 'PUNCT')],
#  [('En', 'PREP'),
#   ('même', 'ADJMS'),
#   ('temps', 'NMS'),
#   ('que', 'COSUB'),
#   ('son', 'DET'),
#   ('rôle', 'NMS'),
#   ('dans', 'PREP'),
#   ('Le', 'DETMS'),
#   ('Caméléon', 'NMS'),
#   ('il', 'PPER3MS'),
#   ('obtient', 'VERB'),
#   ('de', 'DET'),
#   ('petits', 'ADJMP'),
#   ('rôles', 'NMP'),
#   ('dans', 'PREP'),
#   ('Le', 'DETMS'),
#   ('Manipulateur', 'NMS'),
#   ('et', 'COCO'),
#   ("L'", 'DET'),
#   ('amour', 'NMS'),
#   ('égaré', 'VPPMS'),
#   ('.', 'YPFOR')],
#  [('Quatre', 'CHIF'),
#   ('grands', 'ADJMP'),
#   ('groupes', 'NMP'),
#   ('pétroliers', 'ADJMP'),
#   (',', 'PUNCT'),
#   ('les', 'DET'),
#   ('américains', 'NMP'),
#   ('ExxonMobil', 'PROPN'),
#   (',', 'PUNCT'),
#   ('Chevron', 'PROPN'),
#   (',', 'PUNCT'),
#   ('ConocoPhillips', 'PROPN'),
#   ('et', 'COCO'),
#   ("l'", 'DET'),
#   ('anglo-néerlandais', 'NMS'),
#   ('Shell', 'PROPN'),
#   ('joignent', 'VERB'),
#   ('leurs', 'DET'),
#   ('efforts', 'NMP'),
#   ('pour', 'PREP'),
#   ('préparer', 'VERB'),
#   ('un', 'DINTMS'),
#   ('effort', 'NMS'),
#   ('de', 'PREP'),
#   ('réponse', 'NFS'),
#   ('commun', 'ADJMS'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('futures', 'ADJFP'),
#   ('marées', 'NFP'),
#   ('noires', 'ADJFP'),
#   (',', 'PUNCT'),
#   ("d'", 'PREP'),
#   ('après', 'PREP'),
#   ('un', 'DINTMS'),
#   ('communiqué', 'NMS'),
#   ('commun', 'ADJMS'),
#   ('publié', 'VPPMS'),
#   ('mercredi', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('fait', 'VERB'),
#   ('partie', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('clubs', 'NMP'),
#   ('fondateurs', 'ADJMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('deuxième', 'ADJMS'),
#   ('niveau', 'NMS'),
#   ('national', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('baptisé', 'VPPMS'),
#   ('Promotion', 'PROPN'),
#   (',', 'PUNCT'),
#   ('en', 'PREP'),
#   ('1909', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('village', 'NMS'),
#   ('culmine', 'VERB'),
#   ('à', 'PREP'),
#   ('600', 'CHIF'),
#   ('m', 'NMP'),
#   ('sur', 'PREP'),
#   ('un', 'DINTMS'),
#   ('site', 'NMS'),
#   ('escarpé', 'ADJMS'),
#   ("s'", 'PREF'),
#   ('allongeant', 'VERB'),
#   ('sur', 'PREP'),
#   ('une', 'DINTFS'),
#   ('longue', 'ADJFS'),
#   ('arête', 'NFS'),
#   ('rocheuse', 'ADJFS'),
#   ('grise', 'ADJFS'),
#   ('et', 'COCO'),
#   ('domine', 'VERB'),
#   ('la', 'DETFS'),
#   ('vallée', 'NFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Cernon', 'PROPN'),
#   ('tout', 'ADV'),
#   ('en', 'PREP'),
#   ('étant', 'AUX'),
#   ('abrité', 'VPPMS'),
#   ('par', 'PREP'),
#   ('le', 'DETMS'),
#   ('plateau', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Larzac', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('vieille-ville', 'NFS'),
#   ('de', 'PREP'),
#   ('Krouchevo', 'PROPN'),
#   ('fut', 'AUX'),
#   ('notamment', 'ADV'),
#   ('visitée', 'VPPFS'),
#   ('par', 'PREP'),
#   ('Le', 'DETMS'),
#   ('Corbusier', 'PROPN'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('apprécia', 'VERB'),
#   ('grandement', 'ADV'),
#   ("l'", 'DET'),
#   ('ensemble', 'NMS'),
#   ('compact', 'ADJMS'),
#   ('de', 'PREP'),
#   ('maisons', 'NFP'),
#   ('caractérisées', 'VPPFP'),
#   ('par', 'PREP'),
#   ('des', 'DET'),
#   ('couleurs', 'NFP'),
#   ('vives', 'ADJFP'),
#   (',', 'PUNCT'),
#   ('des', 'DET'),
#   ('balcons', 'NMP'),
#   (',', 'PUNCT'),
#   ('des', 'DET'),
#   ('porches', 'NMP'),
#   ('et', 'COCO'),
#   ('de', 'DET'),
#   ('lourdes', 'ADJFP'),
#   ('portes', 'NFP'),
#   ('de', 'PREP'),
#   ('bois', 'NOUN'),
#   ('.', 'YPFOR')],
#  [('De', 'PREP'),
#   ('plus', 'ADV'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('double', 'ADJMS'),
#   ('homicide', 'NMS'),
#   ('commis', 'VERB'),
#   ('sur', 'PREP'),
#   ('un', 'DINTMS'),
#   ('couple', 'NMS'),
#   ('avait', 'AUX'),
#   ('eu', 'VPPMS'),
#   ('lieu', 'NMS'),
#   ('sur', 'PREP'),
#   ('le', 'DETMS'),
#   ('parking', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('cimetière', 'NMS'),
#   ('de', 'PREP'),
#   ('Laigneville', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('De', 'DET'),
#   ('nombreux', 'ADJMP'),
#   ('pays', 'NMP'),
#   ('où', 'ADV'),
#   ('la', 'DETFS'),
#   ('maladie', 'NFS'),
#   ('sévit', 'VERB'),
#   ('ont', 'VERB'),
#   ('une', 'DINTFS'),
#   ('association', 'NFS'),
#   ("d'", 'PREP'),
#   ('aide', 'NFS'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('malades', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Au-delà', 'ADV'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('adaptation', 'NFS'),
#   ('concrète', 'ADJFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('texte', 'NMS'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('besoins', 'NMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('film', 'NMS'),
#   (',', 'PUNCT'),
#   ('Kiarostami', 'PROPN'),
#   ('commence', 'VERB'),
#   ('souvent', 'ADV'),
#   (',', 'PUNCT'),
#   ('ostensiblement', 'ADV'),
#   (',', 'PUNCT'),
#   ('par', 'PREP'),
#   ('fournir', 'VERB'),
#   ('une', 'DINTFS'),
#   ('métaphore', 'NFS'),
#   ('visuelle', 'ADJFS'),
#   ('de', 'PREP'),
#   ('certaines', 'DET'),
#   ('techniques', 'NFP'),
#   ('spécifiques', 'ADJFP'),
#   ('de', 'PREP'),
#   ('montage', 'NMS'),
#   ('dans', 'PREP'),
#   ('la', 'DETFS'),
#   ('poésie', 'NFS'),
#   ('persane', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('classique', 'ADJFS'),
#   ('ou', 'COCO'),
#   ('moderne', 'ADJFS'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('travaille', 'VERB'),
#   ('sur', 'PREP'),
#   ('une', 'DINTFS'),
#   ('publication', 'NFS'),
#   ('exhaustive', 'ADJFS'),
#   ('sur', 'PREP'),
#   ('le', 'DETMS'),
#   ('sujet', 'NMS'),
#   ('avec', 'PREP'),
#   ('Hugh', 'PROPN'),
#   ('Whistler', 'XFAMIL'),
#   ('quand', 'COSUB'),
#   ('il', 'PPER3MS'),
#   ('meurt', 'VERB'),
#   ('en', 'PREP'),
#   ('1941', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('En', 'PREP'),
#   ('1996', 'CHIF'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('augmente', 'VERB'),
#   ('la', 'DETFS'),
#   ('capacité', 'NFS'),
#   ('de', 'PREP'),
#   ('son', 'DET'),
#   ('usine', 'NFS'),
#   ("d'", 'PREP'),
#   ('Abidjan', 'PROPN'),
#   ('pour', 'PREP'),
#   ('la', 'PPOBJFS'),
#   ('porter', 'VERB'),
#   ('de', 'PREP'),
#   ('21500', 'CHIF'),
#   ('tonnes', 'NFP'),
#   ('à', 'PREP'),
#   ('86000', 'CHIF'),
#   ('tonnes', 'NFP'),
#   ('de', 'PREP'),
#   ('cacao', 'NMS'),
#   ('.', 'YPFOR')],
#  [('William', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('Willy', 'PROPN'),
#   (')', 'PUNCT'),
#   ('Ostijn', 'XFAMIL'),
#   ('(', 'PUNCT'),
#   ('1913-1993', 'CHIF'),
#   (')', 'PUNCT'),
#   ('est', 'AUX'),
#   ('un', 'DINTMS'),
#   ('compositeur', 'NMS'),
#   ('belge', 'ADJMS'),
#   ('néoclassique', 'ADJMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('milieu', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('XXe', 'ADJMS'),
#   ('siècle', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Présidée', 'VPPFS'),
#   ('par', 'PREP'),
#   ('Henri', 'PROPN'),
#   ('Jooris', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('la', 'DETFS'),
#   ('Ligue', 'NFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Nord', 'NMS'),
#   ('crée', 'VERB'),
#   ('notamment', 'ADV'),
#   ('la', 'DETFS'),
#   ('Division', 'NFS'),
#   ("d'", 'PREP'),
#   ('Honneur', 'NMS'),
#   (',', 'PUNCT'),
#   ('plus', 'ADV'),
#   ('haut', 'ADJMS'),
#   ('niveau', 'NMS'),
#   ('régional', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('la', 'DETFS'),
#   ('Promotion', 'NFS'),
#   ("d'", 'PREP'),
#   ('Honneur', 'NMS'),
#   (',', 'PUNCT'),
#   ('deuxième', 'ADJFS'),
#   ('division', 'NFS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Ligue', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Ce', 'PDEMMS'),
#   ('qui', 'PREL'),
#   ('représente', 'VERB'),
#   ('un', 'DINTMS'),
#   ('choix', 'NMS'),
#   ('de', 'PREP'),
#   ('plus', 'ADV'),
#   ('de', 'PREP'),
#   ("10'000", 'CHIF'),
#   ('bijoux', 'NMP'),
#   ('de', 'PREP'),
#   ('piercing', 'NMS'),
#   ('en', 'PREP'),
#   ('stock', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Bonne', 'ADJFS'),
#   ('nourriture', 'NFS'),
#   ('mais', 'COCO'),
#   ('le', 'DETMS'),
#   ('temps', 'NMS'),
#   ("d'", 'PREP'),
#   ('attente', 'NFS'),
#   ('entre', 'PREP'),
#   ('les', 'DET'),
#   ('plats', 'NMP'),
#   ('a', 'AUX'),
#   ('été', 'AUX'),
#   ('très', 'ADV'),
#   ('long', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [("N'", 'ADV'),
#   ('en', 'PPOBJMS'),
#   ('voyant', 'VERB'),
#   ('pas', 'ADV'),
#   ("l'", 'DET'),
#   ('utilité', 'NFS'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ("l'", 'PPER3MS'),
#   ('offre', 'VERB'),
#   ('à', 'PREP'),
#   ('Marge', 'PROPN'),
#   ('Simpson', 'XFAMIL'),
#   ('qui', 'PREL'),
#   (',', 'PUNCT'),
#   ('en', 'PREP'),
#   ('échange', 'NMS'),
#   (',', 'PUNCT'),
#   ('accepte', 'VERB'),
#   ('de', 'PREP'),
#   ('garder', 'VERB'),
#   ('Rod', 'PROPN'),
#   ('et', 'COCO'),
#   ('Todd', 'PROPN'),
#   ('pendant', 'PREP'),
#   ('que', 'COSUB'),
#   ('Ned', 'PROPN'),
#   ('Flanders', 'XFAMIL'),
#   ('se', 'PREF'),
#   ('rend', 'VERB'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('congrès', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('gauchers', 'NMP'),
#   ('.', 'YPFOR')],
#  [('GD', 'PROPN'),
#   (')', 'PUNCT'),
#   ('est', 'AUX'),
#   ('une', 'PINDFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('divisions', 'NFP'),
#   ("d'", 'PREP'),
#   ('infanterie', 'NFS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('armée', 'NFS'),
#   ('allemande', 'ADJFS'),
#   ('(', 'PUNCT'),
#   ('Wehrmacht', 'PROPN'),
#   (')', 'PUNCT'),
#   ('durant', 'PREP'),
#   ('la', 'DETFS'),
#   ('Seconde', 'ADJFS'),
#   ('Guerre', 'NFS'),
#   ('mondiale', 'ADJFS'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('parlait', 'VERB'),
#   ("d'", 'PREP'),
#   ('horribles', 'ADJMP'),
#   ('évènements', 'NMP'),
#   ('qui', 'PREL'),
#   ('se', 'PREF'),
#   ('déroulaient', 'VERB'),
#   ('dans', 'PREP'),
#   ('les', 'DET'),
#   ('villes', 'NFP'),
#   ('où', 'ADV'),
#   ('une', 'DINTFS'),
#   ('femme', 'NFS'),
#   ('particulière', 'ADJFS'),
#   ('passait', 'VERB'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('fossés', 'NMP'),
#   (',', 'PUNCT'),
#   ('de', 'PREP'),
#   ('«', 'PUNCT'),
#   ('cent', 'CHIF'),
#   ('pieds', 'NMP'),
#   ('de', 'PREP'),
#   ('long', 'NMS'),
#   ('»', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('sur', 'PREP'),
#   ('chaque', 'DET'),
#   ('face', 'NFS'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ('«', 'PUNCT'),
#   ('quinze', 'CHIF'),
#   ('de', 'PREP'),
#   ('profondeur', 'NFS'),
#   ('»', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('existaient', 'VERB'),
#   ('encore', 'ADV'),
#   ('en', 'PREP'),
#   ('partie', 'NFS'),
#   ('vers', 'PREP'),
#   ('1865', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('arrive', 'VERB'),
#   ('de', 'PREP'),
#   ('Mutzig', 'PROPN'),
#   ('en', 'PREP'),
#   ('1966', 'CHIF'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('SCO', 'PROPN'),
#   ('Angers', 'XFAMIL'),
#   ('où', 'ADV'),
#   ('il', 'PPER3MS'),
#   ('joue', 'VERB'),
#   ('entre', 'PREP'),
#   ('les', 'DET'),
#   ('saisons', 'NFP'),
#   ('1966-67', 'CHIF'),
#   ('et', 'COCO'),
#   ('1976-1977', 'CHIF'),
#   ('soit', 'ADV'),
#   ('11', 'CHIF'),
#   ('saisons', 'NFP'),
#   ('(', 'PUNCT'),
#   ('dont', 'PREL'),
#   ('2', 'CHIF'),
#   ('en', 'PREP'),
#   ('2', 'CHIF'),
#   ('division', 'NFS'),
#   (')', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('En', 'PREP'),
#   ('mélangeant', 'VERB'),
#   ('le', 'DETMS'),
#   ('calvados', 'NMS'),
#   ('avec', 'PREP'),
#   ('du', 'DINTMS'),
#   ('jus', 'NMS'),
#   ('de', 'PREP'),
#   ('pomme', 'NFS'),
#   (',', 'PUNCT'),
#   ('on', 'PINDMS'),
#   ('obtient', 'VERB'),
#   ('le', 'DETMS'),
#   ('pommeau', 'NMS'),
#   ('de', 'PREP'),
#   ('Normandie', 'PROPN'),
#   (',', 'PUNCT'),
#   ('qui', 'PREL'),
#   ('titre', 'VERB'),
#   ('entre', 'PREP'),
#   ('16', 'CHIF'),
#   ('°', 'SYM'),
#   ('et', 'COCO'),
#   ('18', 'CHIF'),
#   ('°', 'SYM'),
#   ("d'", 'PREP'),
#   ('alcool', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Traian', 'PROPN'),
#   ('Popovici', 'XFAMIL'),
#   ('(', 'PUNCT'),
#   ('né', 'VPPMS'),
#   ('le', 'DETMS'),
#   ('17', 'CHIF'),
#   ('octobre', 'NMS'),
#   ('1892', 'CHIF'),
#   ('dans', 'PREP'),
#   ('le', 'DETMS'),
#   ('village', 'NMS'),
#   ('de', 'PREP'),
#   ('Ruşii-Mănăstioara', 'PROPN'),
#   (',', 'PUNCT'),
#   ('en', 'PREP'),
#   ('Bucovine', 'PROPN'),
#   (',', 'PUNCT'),
#   ('alors', 'ADV'),
#   ('en', 'PREP'),
#   ('Autriche-Hongrie', 'PROPN'),
#   (',', 'PUNCT'),
#   ('mort', 'VPPMS'),
#   ('le', 'DETMS'),
#   ('4', 'CHIF'),
#   ('juin', 'NMS'),
#   ('1946', 'CHIF'),
#   (',', 'PUNCT'),
#   ('dans', 'PREP'),
#   ('le', 'DETMS'),
#   ('hameau', 'NMS'),
#   ('de', 'PREP'),
#   ('Colacu', 'PROPN'),
#   (',', 'PUNCT'),
#   ('commune', 'NFS'),
#   ('de', 'PREP'),
#   ('Fundu', 'PROPN'),
#   ('Moldovei', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('judeţ', 'NMS'),
#   ('de', 'PREP'),
#   ('Suceava', 'PROPN'),
#   (',', 'PUNCT'),
#   ('Bucovine', 'PROPN'),
#   (',', 'PUNCT'),
#   ('Roumanie', 'PROPN'),
#   (')', 'PUNCT'),
#   ('est', 'AUX'),
#   ('un', 'DINTMS'),
#   ('avocat', 'NMS'),
#   ('roumain', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('compté', 'VPPMS'),
#   ('parmi', 'PREP'),
#   ('les', 'DET'),
#   ('Justes', 'NMP'),
#   ('pour', 'PREP'),
#   ('avoir', 'AUX'),
#   (',', 'PUNCT'),
#   ('pendant', 'PREP'),
#   ('la', 'DETFS'),
#   ('Deuxième', 'ADJFS'),
#   ('Guerre', 'NFS'),
#   ('mondiale', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('sauvé', 'VPPMS'),
#   ('près', 'ADV'),
#   ('de', 'PREP'),
#   ('20 000', 'CHIF'),
#   ('juifs', 'NMP'),
#   ('roumains', 'ADJMP'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Shoah', 'PROPN'),
#   ('roumaine', 'ADJFS'),
#   ('mise', 'VPPFS'),
#   ('en', 'PREP'),
#   ('œuvre', 'NFS'),
#   ('par', 'PREP'),
#   ('le', 'DETMS'),
#   ('régime', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('"', 'PUNCT'),
#   ('Pétain', 'PROPN'),
#   ('roumain', 'ADJMS'),
#   ('"', 'PUNCT'),
#   ('(', 'PUNCT'),
#   ('comme', 'COSUB'),
#   ('il', 'PPER3MS'),
#   ('se', 'PREF'),
#   ('qualifiait', 'VERB'),
#   ('lui-même', 'PPOBJMS'),
#   (')', 'PUNCT'),
#   (':', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('maréchal', 'NMS'),
#   ('Ion', 'PROPN'),
#   ('Antonescu', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  ...]

# %%
train_sents
# Out:
# [[('Les', 'DET'),
#   ('commotions', 'NFP'),
#   ('cérébrales', 'ADJFP'),
#   ('sont', 'AUX'),
#   ('devenu', 'VPPMS'),
#   ('si', 'ADV'),
#   ('courantes', 'ADJFP'),
#   ('dans', 'PREP'),
#   ('ce', 'PDEMMS'),
#   ('sport', 'NMS'),
#   ("qu'", 'COSUB'),
#   ('on', 'PINDMS'),
#   ('les', 'PPOBJMS'),
#   ('considére', 'VERB'),
#   ('presque', 'ADV'),
#   ('comme', 'PREP'),
#   ('la', 'DETFS'),
#   ('routine', 'NFS'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('œuvre', 'NFS'),
#   ('est', 'AUX'),
#   ('située', 'VPPFS'),
#   ('dans', 'PREP'),
#   ('la', 'DETFS'),
#   ('galerie', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('batailles', 'NFP'),
#   (',', 'PUNCT'),
#   ('dans', 'PREP'),
#   ('le', 'DETMS'),
#   ('château', 'NMS'),
#   ('de', 'PREP'),
#   ('Versailles', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('comportement', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Turquie', 'PROPN'),
#   ('vis-à-vis', 'ADV'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('problème', 'NMS'),
#   ('palestinien', 'ADJMS'),
#   ('a', 'AUX'),
#   ('fait', 'VPPMS'),
#   ("qu'", 'COSUB'),
#   ('elle', 'PPER3FS'),
#   ("n'", 'ADV'),
#   ('est', 'VERB'),
#   ('plus', 'ADV'),
#   ('en', 'PREP'),
#   ('odeur', 'NFS'),
#   ('de', 'PREP'),
#   ('sainteté', 'NFS'),
#   ('auprès', 'ADV'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('communauté', 'NFS'),
#   ('juive', 'ADJFS'),
#   ('en', 'PREP'),
#   ('générale', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('américaine', 'ADJFS'),
#   ('en', 'PREP'),
#   ('particulier', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('Toutefois', 'ADV'),
#   (',', 'PUNCT'),
#   ('les', 'DET'),
#   ('filles', 'NFP'),
#   ('adorent', 'VERB'),
#   ('les', 'DET'),
#   ('desserts', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Ismene', 'PROPN'),
#   ('entre', 'VERB'),
#   ('et', 'COCO'),
#   ('annonce', 'VERB'),
#   ('que', 'COSUB'),
#   ("c'", 'PDEMMS'),
#   ('est', 'AUX'),
#   ('Farnace', 'PROPN'),
#   ('qui', 'PREL'),
#   ('a', 'AUX'),
#   ('mis', 'VERB'),
#   ('le', 'DETMS'),
#   ('feu', 'NMS'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('flotte', 'NFS'),
#   ('romaine', 'ADJFS'),
#   ('.', 'YPFOR')],
#  [('je', 'PPER1S'),
#   ('reviendrais', 'VERB'),
#   ('avec', 'PREP'),
#   ('plaisir', 'NMS'),
#   ('!', 'PUNCT')],
#  [('Les', 'DET'),
#   ('forfaits', 'NMP'),
#   ('comprennent', 'VERB'),
#   ('le', 'DETMS'),
#   ('transport', 'NMS'),
#   ('en', 'PREP'),
#   ('car', 'NMS'),
#   ('Grand', 'ADJMS'),
#   ('Tourisme', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('différents', 'ADJMP'),
#   ('lieux', 'NMP'),
#   ('de', 'PREP'),
#   ('départs', 'NMP'),
#   ('proposés', 'VPPMP'),
#   ('autour', 'ADV'),
#   ('de', 'PREP'),
#   ('Lyon', 'PROPN'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('forfait', 'NMS'),
#   ('de', 'PREP'),
#   ('ski', 'NMS'),
#   ('sur', 'PREP'),
#   ('le', 'DETMS'),
#   ('domaine', 'NMS'),
#   ('cité', 'VPPMS'),
#   (',', 'PUNCT'),
#   ('un', 'DINTMS'),
#   ('en-cas', 'NMS'),
#   ('petit-déjeuner', 'NMS'),
#   ('servi', 'VPPMS'),
#   ('à', 'PREP'),
#   ('votre', 'DET'),
#   ('arrivée', 'NFS'),
#   ('en', 'PREP'),
#   ('station', 'NFS'),
#   ('et', 'COCO'),
#   ('le', 'DETMS'),
#   ('service', 'NMS'),
#   ("d'", 'PREP'),
#   ('un', 'DINTMS'),
#   ('accompagnateur', 'NMS'),
#   ('salarié', 'ADJMS'),
#   ('assurant', 'VERB'),
#   ('la', 'DETFS'),
#   ('logistique', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('départs', 'NMP'),
#   ('et', 'COCO'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('retours', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('prévient', 'VERB'),
#   ('que', 'COSUB'),
#   ('de', 'DET'),
#   ('telles', 'ADJFP'),
#   ('agressions', 'NFP'),
#   ('sont', 'AUX'),
#   ('"', 'PUNCT'),
#   ('susceptibles', 'ADJFP'),
#   ("d'", 'PREP'),
#   ('entraîner', 'VERB'),
#   ('des', 'DET'),
#   ('poursuites', 'NFP'),
#   ('judiciaires', 'ADJFP'),
#   ('"', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Ils', 'PPER3MP'),
#   ('tiraient', 'VERB'),
#   ('à', 'PREP'),
#   ('balles', 'NFP'),
#   ('réelles', 'ADJFP'),
#   ('sur', 'PREP'),
#   ('la', 'DETFS'),
#   ('foule', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('château', 'NMS'),
#   ('est', 'AUX'),
#   ('ensuite', 'ADV'),
#   ('vendu', 'VPPMS'),
#   ('plusieurs', 'DET'),
#   ('fois', 'NFP'),
#   (';', 'PUNCT')],
#  [('En', 'PREP'),
#   ('effet', 'NMS'),
#   (',', 'PUNCT'),
#   ('la', 'DETFS'),
#   ('biréfringence', 'NFS'),
#   ("n'", 'ADV'),
#   ('étant', 'AUX'),
#   ('pas', 'ADV'),
#   ('visible', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('elle', 'PPER3FS'),
#   ("n'", 'ADV'),
#   ('est', 'AUX'),
#   ('pas', 'ADV'),
#   ('prépondérante', 'ADJFS'),
#   ('sur', 'PREP'),
#   ('le', 'DETMS'),
#   ('pouvoir', 'NMS'),
#   ('rotatoire', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('point', 'NMS'),
#   ('final', 'ADJMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('plate-forme', 'NFS'),
#   ('de', 'PREP'),
#   ('distribution', 'NFS'),
#   ('serait', 'AUX'),
#   ('basé', 'VPPMS'),
#   ('en', 'PREP'),
#   ('Autriche', 'PROPN'),
#   ('à', 'PREP'),
#   ('Baumgarten', 'PROPN'),
#   ('pour', 'PREP'),
#   ('rejoindre', 'VERB'),
#   ('ensuite', 'ADV'),
#   ('le', 'DETMS'),
#   ('réseau', 'NMS'),
#   ("d'", 'PREP'),
#   ('Europe', 'PROPN'),
#   ('centrale', 'ADJFS'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('ouest', 'NMS'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('information', 'NFS'),
#   ('génétique', 'ADJFS'),
#   ('est', 'AUX'),
#   ('codée', 'VPPFS'),
#   ('sous', 'PREP'),
#   ('forme', 'NFS'),
#   ("d'", 'PREP'),
#   ('ADN', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Motivé', 'VPPMS'),
#   ('par', 'PREP'),
#   ('la', 'DETFS'),
#   ('charité', 'NFS'),
#   ('chrétienne', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('la', 'DETFS'),
#   ('communauté', 'NFS'),
#   ('a', 'AUX'),
#   ('changé', 'VPPMS'),
#   ('un', 'DINTMS'),
#   ('vieil', 'ADJMS'),
#   ('immeuble', 'NMS'),
#   ('abanbonné', 'VPPMS'),
#   ('où', 'ADV'),
#   ('se', 'PREF'),
#   ('pratiquaient', 'VERB'),
#   ("d'", 'PREP'),
#   ('ailleurs', 'ADV'),
#   ('de', 'DET'),
#   ('nombreux', 'ADJMP'),
#   ('échanges', 'NMP'),
#   ('de', 'PREP'),
#   ('drogues', 'NFP'),
#   ('en', 'PREP'),
#   ('ce', 'PDEMMS'),
#   ('logement', 'NMS'),
#   ('sûr', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('propre', 'ADJMS'),
#   ('et', 'COCO'),
#   ('abordable', 'ADJMS'),
#   ("qu'", 'PREL'),
#   ('il', 'PPER3MS'),
#   ('est', 'AUX'),
#   ("aujourd'hui", 'ADV'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('exploitait', 'VERB'),
#   ('un', 'DINTMS'),
#   ('site', 'NMS'),
#   ('de', 'PREP'),
#   ('haute', 'ADJFS'),
#   ('valeur', 'NFS'),
#   ('militaire', 'ADJFS'),
#   ('et', 'COCO'),
#   ('commerciale', 'ADJFS'),
#   ('comprenant', 'VERB'),
#   ('un', 'DINTMS'),
#   ('surplomb', 'NMS'),
#   ('rocheux', 'ADJ'),
#   ('dominant', 'VERB'),
#   ('en', 'PREP'),
#   ('à-pic', 'NMS'),
#   ('la', 'DETFS'),
#   ('rivière', 'NFS'),
#   ('Oust', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Plus', 'ADV'),
#   ('tard', 'ADV'),
#   ('dans', 'PREP'),
#   ('la', 'DETFS'),
#   ('saison', 'NFS'),
#   (',', 'PUNCT'),
#   ('ils', 'PPER3MP'),
#   ('consomment', 'VERB'),
#   ('beaucoup', 'ADV'),
#   ('de', 'PREP'),
#   ('baies', 'NFP'),
#   ('et', 'COCO'),
#   ('autres', 'ADJMP'),
#   ('petits', 'ADJMP'),
#   ('fruits', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Ils', 'PPER3MP'),
#   ('deviennent', 'VERB'),
#   ('alors', 'ADV'),
#   ('les', 'DET'),
#   ('Paladins', 'PROPN'),
#   (',', 'PUNCT'),
#   ('chevaliers', 'NMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('bien', 'NMS'),
#   ('chargés', 'VPPMP'),
#   ('de', 'PREP'),
#   ('défendre', 'VERB'),
#   ('élèves', 'NMP'),
#   ('et', 'COCO'),
#   ('professeurs', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('chevalier', 'NMS'),
#   ('lui', 'PPOBJMS'),
#   ('propose', 'VERB'),
#   ('une', 'DINTFS'),
#   ('partie', 'NFS'),
#   ("d'", 'PREP'),
#   ('échecs', 'NMP'),
#   (',', 'PUNCT'),
#   ('espérant', 'VERB'),
#   ('retarder', 'VERB'),
#   ("l'", 'DET'),
#   ('échéance', 'NFS'),
#   ('fatidique', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('temps', 'NMS'),
#   ('de', 'PREP'),
#   ('trouver', 'VERB'),
#   ('une', 'DINTFS'),
#   ('solution', 'NFS'),
#   ('à', 'PREP'),
#   ('ses', 'DET'),
#   ('problèmes', 'NMP'),
#   ('métaphysiques', 'ADJMP'),
#   (':', 'PUNCT'),
#   ('Dieu', 'PROPN'),
#   ('existe', 'VERB'),
#   ('-il', 'PPER3MS'),
#   ('?', 'PUNCT')],
#  [('Créée', 'VPPFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('cours', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('troisième', 'ADJMS'),
#   ('trimestre', 'NMS'),
#   ('1915', 'CHIF'),
#   ('comme', 'PREP'),
#   ('escadrille', 'NFS'),
#   ('MF', 'PROPN'),
#   ('93', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('elle', 'PPER3FS'),
#   ('a', 'AUX'),
#   ('disparu', 'VPPMS'),
#   ('en', 'PREP'),
#   ('même', 'ADJMS'),
#   ('temps', 'NMS'),
#   ('que', 'COSUB'),
#   ('la', 'DETFS'),
#   ('30e', 'ADJFS'),
#   ('Escadre', 'NFS'),
#   ('de', 'PREP'),
#   ('Chasse', 'NFS'),
#   ('à', 'PREP'),
#   ('laquelle', 'PRELFS'),
#   ('elle', 'PPER3FS'),
#   ('était', 'AUX'),
#   ('intégrée', 'ADJFS'),
#   ('.', 'YPFOR')],
#  [('On', 'PINDMS'),
#   ('ne', 'ADV'),
#   ('peut', 'VERB'),
#   ('éviter', 'VERB'),
#   ('de', 'PREP'),
#   ('penser', 'VERB'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('actualité', 'NFS'),
#   ('caractérisée', 'VPPFS'),
#   ('par', 'PREP'),
#   ("l'", 'DET'),
#   ('enlèvement', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('otages', 'NMP'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Niger', 'PROPN'),
#   ('--', 'PUNCT'),
#   ('dont', 'PREL'),
#   ('cinq', 'CHIF'),
#   ('Français', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ('est', 'AUX'),
#   ('déjà', 'ADV'),
#   ('soumise', 'VPPFS'),
#   ('à', 'PREP'),
#   ('rude', 'ADJFS'),
#   ('épreuve', 'NFS'),
#   ('avant', 'PREP'),
#   ('même', 'ADV'),
#   ("l'", 'DET'),
#   ('avènement', 'NMS'),
#   ('de', 'PREP'),
#   ('Flann', 'PROPN'),
#   ('Sinna', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [('"', 'PUNCT'),
#   ('Malgré', 'PREP'),
#   ('les', 'DET'),
#   ('efforts', 'NMP'),
#   ('consentis', 'VPPMP'),
#   ('par', 'PREP'),
#   ('quelques', 'DET'),
#   ('pays', 'NMP'),
#   (',', 'PUNCT'),
#   ('environ', 'ADV'),
#   ('155', 'CHIF'),
#   ('millions', 'NMP'),
#   ('de', 'PREP'),
#   ('personnes', 'NFP'),
#   ('--', 'PUNCT'),
#   ('soit', 'ADV'),
#   ('39', 'CHIF'),
#   ('%', 'SYM'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('population', 'NFS'),
#   ('--', 'PUNCT'),
#   ("n'", 'ADV'),
#   ('ont', 'VERB'),
#   ('pas', 'ADV'),
#   ('encore', 'ADV'),
#   ('accès', 'NOUN'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('eau', 'NFS'),
#   ('potable', 'ADJFS'),
#   ('en', 'PREP'),
#   ('Afrique', 'PROPN'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('Ouest', 'PROPN'),
#   ('et', 'COCO'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Centre', 'PROPN'),
#   ('"', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('selon', 'PREP'),
#   ('le', 'DETMS'),
#   ('texte', 'NMS'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('direction', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('fibres', 'NFP'),
#   ('est', 'AUX'),
#   ('donc', 'ADV'),
#   ('la', 'DETFS'),
#   ('direction', 'NFS'),
#   ('de', 'PREP'),
#   ('plus', 'ADV'),
#   ('grande', 'ADJFS'),
#   ('diffusivité', 'NFS'),
#   (',', 'PUNCT'),
#   ('indiquée', 'VPPFS'),
#   ('par', 'PREP'),
#   ('le', 'DETMS'),
#   ('vecteur', 'NMS'),
#   ('propre', 'ADJMS'),
#   ('associé', 'VPPMS'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('plus', 'ADV'),
#   ('grande', 'ADJFS'),
#   ('valeur', 'NFS'),
#   ('propre', 'ADJFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('tenseur', 'NMS'),
#   ('de', 'PREP'),
#   ('diffusion', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('experts', 'NMP'),
#   ('sont', 'AUX'),
#   ('unanimes', 'ADJMP'),
#   ('pour', 'PREP'),
#   ('dater', 'VERB'),
#   ('ce', 'PDEMMS'),
#   ('manuscrit', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('VIe', 'ADJMS'),
#   ('siècle', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ("s'", 'PREF'),
#   ('étend', 'VERB'),
#   ('sur', 'PREP'),
#   ('105,3', 'CHIF'),
#   ('km²', 'NMP'),
#   ('et', 'COCO'),
#   ('comptait', 'VERB'),
#   ('5633', 'CHIF'),
#   ('habitants', 'NMP'),
#   ('en', 'PREP'),
#   ('2010', 'CHIF'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('affaire', 'NFS'),
#   ('se', 'PREF'),
#   ('complique', 'VERB'),
#   ('un', 'DINTMS'),
#   ('peu', 'ADV'),
#   ('avec', 'PREP'),
#   ('les', 'DET'),
#   ('jeux', 'NMP'),
#   ('Super', 'PROPN'),
#   ('Nintendo', 'XFAMIL'),
#   ('ou', 'COCO'),
#   ("d'", 'PREP'),
#   ('autres', 'ADJMP'),
#   ('systèmes', 'NMP'),
#   (',', 'PUNCT'),
#   ('qui', 'PREL'),
#   ('stockent', 'VERB'),
#   ('les', 'DET'),
#   ('valeurs', 'NFP'),
#   ('RVB', 'MOTINC'),
#   ('absolues', 'ADJFP'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('couleurs', 'NFP'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('cathédrale', 'NFS'),
#   (',', 'PUNCT'),
#   ("l'", 'DET'),
#   ('une', 'PINDFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('plus', 'ADV'),
#   ('vastes', 'ADJFP'),
#   ('églises', 'NFP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('monde', 'NMS'),
#   ('arménien', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('est', 'AUX'),
#   ('bâtie', 'VPPFS'),
#   ('sur', 'PREP'),
#   ('le', 'DETMS'),
#   ('modèle', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('cathédrale', 'NFS'),
#   ("d'", 'PREP'),
#   ('Etchmiadzin', 'PROPN'),
#   (':', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ("s'", 'PREF'),
#   ('agit', 'VERB'),
#   ("d'", 'PREP'),
#   ('une', 'DINTFS'),
#   ('croix', 'NFS'),
#   ('libre', 'ADJFS'),
#   ('dotée', 'VPPFS'),
#   ('de', 'PREP'),
#   ('quatre', 'CHIF'),
#   ('absides', 'NFP'),
#   ('.', 'YPFOR')],
#  [('ARF', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('Application', 'NFS'),
#   ('Roll-over', 'NMS'),
#   ('Facility', 'NFS'),
#   (')', 'PUNCT'),
#   ('est', 'AUX'),
#   ('un', 'DINTMS'),
#   ('logiciel', 'NMS'),
#   ('de', 'PREP'),
#   ('haute', 'ADJFS'),
#   ('disponibilité', 'NFS'),
#   (',', 'PUNCT'),
#   ('fonctionnant', 'VERB'),
#   ('sous', 'PREP'),
#   ('AIX', 'PROPN'),
#   ('sur', 'PREP'),
#   ('les', 'DET'),
#   ('machines', 'NFP'),
#   ('Bull', 'PROPN'),
#   ('Escala', 'XFAMIL'),
#   ('ou', 'COCO'),
#   ('Linux', 'PROPN'),
#   ('sur', 'PREP'),
#   ('les', 'DET'),
#   ('serveurs', 'NMP'),
#   ('Bull', 'PROPN'),
#   ('Novascale', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('Abbé', 'PROPN'),
#   ('Othon', 'PROPN'),
#   ('y', 'PPOBJMP'),
#   ('envoie', 'VERB'),
#   ('Albéric', 'PROPN'),
#   ('accompagné', 'VPPMS'),
#   ('de', 'PREP'),
#   ('quelques', 'DET'),
#   ('moines', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('femelles', 'NFP'),
#   ('peuvent', 'VERB'),
#   ('réaliser', 'VERB'),
#   ('une', 'NUM'),
#   ('à', 'PREP'),
#   ('deux', 'CHIF'),
#   ('portées', 'NFP'),
#   ('par', 'PREP'),
#   ('an', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('printemps', 'NMS'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('automne', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ("s'", 'PREF'),
#   ('agit', 'VERB'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('17e', 'ADJMS'),
#   ('but', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('saison', 'NFS'),
#   ('pour', 'PREP'),
#   ("l'", 'DET'),
#   ('attaquant', 'NMS'),
#   ('finlandais', 'ADJ'),
#   ('.', 'YPFOR')],
#  [('Condamné', 'VPPMS'),
#   ('à', 'PREP'),
#   ('dix', 'CHIF'),
#   ('ans', 'NMP'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('passe', 'VERB'),
#   ('le', 'DETMS'),
#   ('reste', 'NMS'),
#   ('de', 'PREP'),
#   ('sa', 'DET'),
#   ('vie', 'NFS'),
#   ('en', 'PREP'),
#   ('prison', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Stephen', 'PROPN'),
#   ('accuse', 'VERB'),
#   ('Adeang', 'PROPN'),
#   ('et', 'COCO'),
#   ('les', 'DET'),
#   ('autres', 'ADJMP'),
#   ('députés', 'NMP'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('opposition', 'NFS'),
#   ("d'", 'PREP'),
#   ('avoir', 'AUX'),
#   ('voté', 'VPPMS'),
#   ('la', 'DETFS'),
#   ('loi', 'NFS'),
#   ('«', 'PUNCT'),
#   ('après', 'PREP'),
#   ('le', 'DETMS'),
#   ('coucher', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('soleil', 'NMS'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('samedi', 'NMS'),
#   ('de', 'PREP'),
#   ('Pâques', 'PROPN'),
#   ('»', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('«', 'PUNCT'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('lueur', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('bougies', 'NFP'),
#   ('»', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Des', 'DET'),
#   ('panneaux', 'NMP'),
#   ('solaires', 'ADJMP'),
#   ('servent', 'VERB'),
#   ('également', 'ADV'),
#   ('à', 'PREP'),
#   ('chauffer', 'VERB'),
#   ("l'", 'DET'),
#   ('eau', 'NFS'),
#   ('chaude', 'ADJFS'),
#   ('sanitaire', 'ADJFS'),
#   ('.', 'YPFOR')],
#  [('Au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('contraire', 'NMS'),
#   (',', 'PUNCT'),
#   ('la', 'DETFS'),
#   ('rifampicine', 'NFS'),
#   ('diminue', 'VERB'),
#   ('son', 'DET'),
#   ('taux', 'NMS'),
#   ('sérique', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('Ce', 'PDEMMS'),
#   ('mécanisme', 'NMS'),
#   ('peut', 'VERB'),
#   ('permettre', 'VERB'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('fraude', 'NFS'),
#   ('de', 'PREP'),
#   ('durer', 'VERB'),
#   ('plusieurs', 'DET'),
#   ('années', 'NFP'),
#   (';', 'PUNCT')],
#  [('Vous', 'PREFP'),
#   ('pensez', 'VERB'),
#   ('que', 'COSUB'),
#   ('les', 'DET'),
#   ('Mauriciens', 'PROPN'),
#   ('ne', 'ADV'),
#   ('parlent', 'VERB'),
#   ('pas', 'ADV'),
#   ('suffisamment', 'ADV'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('situation', 'NFS'),
#   ('linguistique', 'ADJFS'),
#   ('de', 'PREP'),
#   ('leur', 'DET'),
#   ('pays', 'NMS'),
#   ('?', 'PUNCT')],
#  [('Tout', 'DET'),
#   ('ceci', 'PDEMMS'),
#   ('nous', 'PREFP'),
#   ('conduit', 'VERB'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('désagréable', 'ADJMS'),
#   ('sentiment', 'NMS'),
#   ('que', 'COSUB'),
#   ("l'", 'DET'),
#   ('économie', 'NFS'),
#   ('mondiale', 'ADJFS'),
#   ('se', 'PREF'),
#   ('dirige', 'VERB'),
#   ('tout', 'ADV'),
#   ('droit', 'ADV'),
#   ('vers', 'PREP'),
#   ('la', 'DETFS'),
#   ('déflation', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('hameaux', 'NMP'),
#   ('de', 'PREP'),
#   ('Faÿ', 'PROPN'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ('Barbizon', 'PROPN'),
#   ('lui', 'PPOBJMS'),
#   ('étaient', 'AUX'),
#   ('reliés', 'VPPMP'),
#   ('par', 'PREP'),
#   ('le', 'DETMS'),
#   ('"', 'PUNCT'),
#   ('chemin', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Messe', 'PROPN'),
#   ('"', 'PUNCT'),
#   ('toujours', 'ADV'),
#   ('existant', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('De', 'PREP'),
#   ('plus', 'ADV'),
#   ("l'", 'DET'),
#   ('appartenance', 'NFS'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('ordre', 'NMS'),
#   ('équestre', 'ADJMS'),
#   ('était', 'AUX'),
#   ('nécessaire', 'ADJFS'),
#   ('pour', 'PREP'),
#   ('accéder', 'VERB'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('postes', 'NMP'),
#   ("d'", 'PREP'),
#   ('officier', 'NMS'),
#   ('dans', 'PREP'),
#   ("l'", 'DET'),
#   ('armée', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('Faune', 'PROPN'),
#   ('canarien', 'ADJMS'),
#   ('vole', 'VERB'),
#   ('en', 'PREP'),
#   ('une', 'DINTFS'),
#   ('génération', 'NFS'),
#   ('entre', 'PREP'),
#   ('juin', 'NMS'),
#   ('et', 'COCO'),
#   ('septembre', 'NMS'),
#   ('suivant', 'PREP'),
#   ('la', 'DETFS'),
#   ('sous-espèce', 'NFS'),
#   ('et', 'COCO'),
#   ("l'", 'DET'),
#   ('altitude', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Étant', 'AUX'),
#   ('atteint', 'VPPMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('syndrome', 'NMS'),
#   ('de', 'PREP'),
#   ('Marfan', 'PROPN'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('est', 'AUX'),
#   ('très', 'ADV'),
#   ('grand', 'ADJMS'),
#   ('et', 'COCO'),
#   ('mince', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('faut', 'VERB'),
#   ('attendre', 'VERB'),
#   ('1527', 'CHIF'),
#   ('pour', 'PREP'),
#   ('que', 'COSUB'),
#   ('nous', 'PREFP'),
#   ('parvienne', 'VERB'),
#   ('le', 'DETMS'),
#   ('plus', 'ADV'),
#   ('ancien', 'ADJMS'),
#   ('texte', 'NMS'),
#   (',', 'PUNCT'),
#   ('écrit', 'VPPMS'),
#   ('par', 'PREP'),
#   ('Jan', 'PROPN'),
#   ('Ymbrechts', 'XFAMIL'),
#   ('--', 'PUNCT'),
#   ('sacristain', 'NMS'),
#   ("d'", 'PREP'),
#   ('Evere', 'PROPN'),
#   ('--', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('concernant', 'VERB'),
#   ("l'", 'DET'),
#   ('adjudication', 'NFS'),
#   ("d'", 'PREP'),
#   ('un', 'DINTMS'),
#   ('nouveau', 'ADJMS'),
#   ('chœur', 'NMS'),
#   ('à', 'PREP'),
#   ('cette', 'PDEMFS'),
#   ('église', 'NFS'),
#   ('.', 'YPFOR')],
#  [("D'", 'PREP'),
#   ('un', 'DINTMS'),
#   ('coup', 'NMS'),
#   ('de', 'PREP'),
#   ('pied', 'NMS'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('le', 'PPOBJMS'),
#   ('fait', 'AUX'),
#   ('tomber', 'VERB'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('main', 'NFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('prêtre', 'NMS'),
#   (',', 'PUNCT'),
#   ('par', 'PREP'),
#   ('terre', 'NFS'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('A887', 'NFS'),
#   ('et', 'COCO'),
#   ("l'", 'DET'),
#   ('A87', 'NFS'),
#   ('traversent', 'VERB'),
#   ('Glenmoriston', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('cours', 'NMS'),
#   ('de', 'PREP'),
#   ('dessin', 'NMS'),
#   ('est', 'AUX'),
#   ('il', 'PPER3MS'),
#   ('pour', 'PREP'),
#   ('les', 'DET'),
#   ('débutants', 'NMP'),
#   ('?', 'PUNCT')],
#  [('Bien', 'ADV'),
#   ('que', 'COSUB'),
#   ('cette', 'PDEMFS'),
#   ('entreprise', 'NFS'),
#   ('ait', 'AUX'),
#   ('été', 'AUX'),
#   ('considérée', 'VPPFS'),
#   ('comme', 'COSUB'),
#   ('sans', 'PREP'),
#   ('espoir', 'NMS'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('syndicat', 'NMS'),
#   ('persévéra', 'VERB'),
#   (',', 'PUNCT'),
#   ('même', 'ADV'),
#   ("s'", 'COSUB'),
#   ('il', 'PPER3MS'),
#   ('ne', 'ADV'),
#   ('pouvait', 'VERB'),
#   ('payer', 'VERB'),
#   ('que', 'ADV'),
#   ('huit', 'CHIF'),
#   ('jours', 'NMP'),
#   ('de', 'PREP'),
#   ('recherches', 'NFP'),
#   ('.', 'YPFOR')],
#  [('Tous', 'ADJMP'),
#   ('les', 'DET'),
#   ('matchs', 'NMP'),
#   ('sont', 'AUX'),
#   ('désignés', 'VPPMP'),
#   ('par', 'PREP'),
#   ('tirage', 'NMS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('sort', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Larry', 'PROPN'),
#   ('Harlow', 'XFAMIL'),
#   ('a', 'AUX'),
#   ('fait', 'AUX'),
#   ('découvrir', 'VERB'),
#   ('le', 'DETMS'),
#   ('trompettiste', 'NMS'),
#   ('cubain', 'ADJMS'),
#   ('Alfredo', 'PROPN'),
#   ('"', 'PUNCT'),
#   ('Chocolate', 'NMS'),
#   ('"', 'PUNCT'),
#   ('Armenteros', 'XFAMIL'),
#   ('et', 'COCO'),
#   ('le', 'DETMS'),
#   ('tromboniste', 'NMS'),
#   ('Mark', 'PROPN'),
#   ('Weinstein', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('qui', 'PREL'),
#   ('a', 'AUX'),
#   ('co-arrangé', 'VPPMS'),
#   ("l'", 'DET'),
#   ('album', 'NMS'),
#   ('avec', 'PREP'),
#   ('lui', 'PPOBJMS'),
#   ('.', 'YPFOR')],
#  [('Depuis', 'PREP'),
#   ('1986', 'CHIF'),
#   (',', 'PUNCT'),
#   ('les', 'DET'),
#   ('émissions', 'NFP'),
#   ('de', 'PREP'),
#   ('Radio', 'PROPN'),
#   ('Chine', 'XFAMIL'),
#   ('Internationale', 'ADJFS'),
#   ('sont', 'AUX'),
#   ('relayées', 'VPPFP'),
#   ('par', 'PREP'),
#   ('les', 'DET'),
#   ('émetteurs', 'NMP'),
#   ('français', 'ADJ'),
#   ("d'", 'PREP'),
#   ('Issoudun', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('en', 'PREP'),
#   ('métropole', 'NFS'),
#   (')', 'PUNCT'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ('Montsinéry-Tonnegrande', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('en', 'PREP'),
#   ('Guyane', 'PROPN'),
#   (')', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Englebert', 'PROPN'),
#   ('exprime', 'VERB'),
#   ('son', 'DET'),
#   ('hostilité', 'NFS'),
#   ('et', 'COCO'),
#   ('semble', 'VERB'),
#   ('soutenu', 'VPPMS'),
#   ('par', 'PREP'),
#   ('le', 'DETMS'),
#   ('Cardinal', 'PROPN'),
#   ('Mercier', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Commandité', 'VPPMS'),
#   ('par', 'PREP'),
#   ('son', 'DET'),
#   ('oncle', 'NMS'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('directeur', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('journal', 'NMS'),
#   ('«', 'PUNCT'),
#   ('La', 'DETFS'),
#   ('Tribune', 'PROPN'),
#   ('»', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('la', 'DETFS'),
#   ('journaliste', 'NFS'),
#   ('Diana', 'PROPN'),
#   ('Palmer', 'XFAMIL'),
#   ('se', 'PREF'),
#   ('rend', 'VERB'),
#   ('sur', 'PREP'),
#   ("l'", 'DET'),
#   ('île', 'NFS'),
#   ('de', 'PREP'),
#   ('Benalla', 'PROPN'),
#   ('et', 'COCO'),
#   ('est', 'AUX'),
#   ('kidnappée', 'VPPFS'),
#   ('par', 'PREP'),
#   ('des', 'DET'),
#   ('pirates', 'NMP'),
#   ('...', 'PUNCT')],
#  [('Un', 'DINTMS'),
#   ('membre', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('gouvernement', 'NMS'),
#   ('peut', 'VERB'),
#   ('également', 'ADV'),
#   ('servir', 'VERB'),
#   ('de', 'PREP'),
#   ('porte-parole', 'NMS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('exécutif', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Ironiquement', 'ADV'),
#   (',', 'PUNCT'),
#   ('Trois', 'CHIF'),
#   ('morceaux', 'NMP'),
#   ('en', 'PREP'),
#   ('forme', 'NFS'),
#   ('de', 'PREP'),
#   ('poire', 'NFS'),
#   ('comporte', 'VERB'),
#   ('sept', 'CHIF'),
#   ('mouvements', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Elles', 'PPER3FP'),
#   ('faisaient', 'VERB'),
#   ("l'", 'DET'),
#   ('objet', 'NMS'),
#   ("d'", 'PREP'),
#   ('un', 'DINTMS'),
#   ('ordre', 'NMS'),
#   ('de', 'PREP'),
#   ('recherche', 'NFS'),
#   ('et', 'COCO'),
#   ("d'", 'PREP'),
#   ('arrestation', 'NFS'),
#   ('pour', 'PREP'),
#   ('avoir', 'AUX'),
#   ('participé', 'VPPMS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('camp', 'NMS'),
#   ('--', 'PUNCT'),
#   ('également', 'ADV'),
#   ('dénommé', 'VPPMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Dignité', 'PROPN'),
#   ('--', 'PUNCT'),
#   ('et', 'COCO'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('affrontements', 'NMP'),
#   ('postérieurs', 'ADJMP'),
#   ('qui', 'PREL'),
#   ('ont', 'AUX'),
#   ('eu', 'VPPMS'),
#   ('lieu', 'NMS'),
#   ('dans', 'PREP'),
#   ('les', 'DET'),
#   ('rues', 'NFP'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('ville', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Ce', 'PDEMMS'),
#   ('test', 'NMS'),
#   ('intéresserait', 'VERB'),
#   ('plutôt', 'ADV'),
#   ('les', 'DET'),
#   ('ingénieurs', 'NMP'),
#   ('qui', 'PREL'),
#   ('songent', 'VERB'),
#   ('à', 'PREP'),
#   ('intégrer', 'VERB'),
#   ('ce', 'PDEMMS'),
#   ('moteur', 'NMS'),
#   ('dans', 'PREP'),
#   ('leurs', 'DET'),
#   ('propres', 'ADJMP'),
#   ('développements', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Jabba', 'PROPN'),
#   ('mène', 'VERB'),
#   ('une', 'DINTFS'),
#   ('vie', 'NFS'),
#   ('de', 'PREP'),
#   ('plaisirs', 'NMP'),
#   ('dans', 'PREP'),
#   ('son', 'DET'),
#   ('palais', 'NMS'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('reçoit', 'VERB'),
#   ('les', 'DET'),
#   ('visites', 'NFP'),
#   ('de', 'PREP'),
#   ('célèbres', 'ADJMP'),
#   ('contrebandiers', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Toujours', 'ADV'),
#   ('en', 'PREP'),
#   ('Géométrie', 'NFS'),
#   ('euclidienne', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('on', 'PINDMS'),
#   ('montre', 'VERB'),
#   ('que', 'COSUB'),
#   ('dans', 'PREP'),
#   ('un', 'DINTMS'),
#   ('triangle', 'NMS'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('centre', 'NMS'),
#   ('de', 'PREP'),
#   ('gravité', 'NFS'),
#   ('G', 'MOTINC'),
#   (',', 'PUNCT'),
#   ("l'", 'DET'),
#   ('orthocentre', 'NMS'),
#   ('H', 'SYM'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('centre', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('cercle', 'NMS'),
#   ('circonscrit', 'VPPMS'),
#   ('Ω', 'MOTINC'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('le', 'DETMS'),
#   ('centre', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('cercle', 'NMS'),
#   ("d'", 'PREP'),
#   ('Euler', 'PROPN'),
#   ('E', 'MOTINC'),
#   ('sont', 'AUX'),
#   ('tous', 'ADJMP'),
#   ('les', 'DET'),
#   ('quatre', 'CHIF'),
#   ('alignés', 'VPPMP'),
#   ('sur', 'PREP'),
#   ('une', 'DINTFS'),
#   ('droite', 'NFS'),
#   ('dite', 'VPPFS'),
#   ('droite', 'NFS'),
#   ("d'", 'PREP'),
#   ('Euler', 'PROPN'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('triangle', 'NMS'),
#   (',', 'PUNCT'),
#   ('de', 'PREP'),
#   ('plus', 'ADV'),
#   ('ils', 'PPER3MP'),
#   ('sont', 'AUX'),
#   ('en', 'PREP'),
#   ('division', 'NFS'),
#   ('harmonique', 'ADJFS'),
#   ('(', 'PUNCT'),
#   ('dans', 'PREP'),
#   ('cet', 'PDEMMS'),
#   ('ordre', 'NMS'),
#   (')', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('27', 'CHIF'),
#   ('mai', 'NMS'),
#   ('2011', 'CHIF'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('Président', 'NMS'),
#   ('chargé', 'VPPMS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('instruction', 'NFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Tribunal', 'PROPN'),
#   ('de', 'PREP'),
#   ('grande', 'ADJFS'),
#   ('instance', 'NFS'),
#   ('de', 'PREP'),
#   ('Paris', 'PROPN'),
#   ('rend', 'VERB'),
#   ('une', 'DINTFS'),
#   ('ordonnance', 'NFS'),
#   ('de', 'PREP'),
#   ('non-lieu', 'NMS'),
#   ('pour', 'PREP'),
#   ('charges', 'NFP'),
#   ('insuffisantes', 'ADJFP'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('encontre', 'NFS'),
#   ("d'", 'PREP'),
#   ('Yves', 'PROPN'),
#   ('Poey', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [('Ses', 'DET'),
#   ('habitants', 'NMP'),
#   ('sont', 'AUX'),
#   ('appelés', 'VPPMP'),
#   ('les', 'DET'),
#   ('Paydrets', 'PROPN'),
#   ('et', 'COCO'),
#   ('les', 'DET'),
#   ('Paydrètes', 'PROPN'),
#   (';', 'PUNCT')],
#  [('Bien', 'ADV'),
#   ('évidemment', 'ADV'),
#   ('tous', 'ADJMP'),
#   ('les', 'DET'),
#   ('matériaux', 'NMP'),
#   ('de', 'PREP'),
#   ('valeur', 'NFS'),
#   ('avaient', 'AUX'),
#   ('été', 'AUX'),
#   ('prélevés', 'VPPMP'),
#   ('depuis', 'PREP'),
#   ('longtemps', 'ADV'),
#   (',', 'PUNCT'),
#   ('cependant', 'ADV'),
#   ('un', 'DINTMS'),
#   ('certain', 'ADJMS'),
#   ('nombre', 'NMS'),
#   ("d'", 'PREP'),
#   ('artefacts', 'NMP'),
#   ('caractéristiques', 'ADJMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('viatique', 'NMS'),
#   ('funéraire', 'ADJMS'),
#   ('royal', 'ADJMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('XVIIIe', 'ADJFS'),
#   ('dynastie', 'NFS'),
#   ('ont', 'AUX'),
#   ('pu', 'VPPMS'),
#   ('être', 'AUX'),
#   ('retrouvés', 'VPPMP'),
#   ('et', 'COCO'),
#   ('dont', 'PREL'),
#   ('le', 'DETMS'),
#   ('tombeau', 'NMS'),
#   ('de', 'PREP'),
#   ('Toutânkhamon', 'PROPN'),
#   ('livrera', 'VERB'),
#   ('plus', 'ADV'),
#   ('tard', 'ADV'),
#   ('un', 'DINTMS'),
#   ('ensemble', 'NMS'),
#   ('quasi', 'ADV'),
#   ('complet', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('a', 'AUX'),
#   ('sauté', 'VPPMS'),
#   ('sur', 'PREP'),
#   ('Mourinho', 'PROPN'),
#   (',', 'PUNCT'),
#   ('en', 'PREP'),
#   ('demandant', 'VERB'),
#   ('à', 'PREP'),
#   ('haute', 'ADJFS'),
#   ('voix', 'NFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Portugais', 'PROPN'),
#   ('de', 'PREP'),
#   ('respecter', 'VERB'),
#   ('les', 'DET'),
#   ('règles', 'NFP'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ('rester', 'VERB'),
#   ('dans', 'PREP'),
#   ('la', 'DETFS'),
#   ('zone', 'NFS'),
#   ('de', 'PREP'),
#   ('direction', 'NFS'),
#   ('pour', 'PREP'),
#   ('entraîneurs', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ('reste', 'VERB'),
#   ('actuellement', 'ADV'),
#   ('dans', 'PREP'),
#   ("l'", 'DET'),
#   ('attente', 'NFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('verdict', 'NMS'),
#   ('final', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('Des', 'DET'),
#   ('innocents', 'NMP'),
#   ('se', 'PREF'),
#   ('trouvent', 'VERB'),
#   ('impliqués', 'VPPMP'),
#   ('dans', 'PREP'),
#   ('des', 'DET'),
#   ('affaires', 'NFP'),
#   ('comme', 'PREP'),
#   ('celle-ci', 'PDEMFS'),
#   ('alors', 'ADV'),
#   ("qu'", 'COSUB'),
#   ('ils', 'PPER3MP'),
#   ('sont', 'AUX'),
#   ('en', 'PREP'),
#   ('fait', 'NMS'),
#   ('utilisés', 'VPPMP'),
#   ('dans', 'PREP'),
#   ('des', 'DET'),
#   ('stratagèmes', 'NMP'),
#   ('politiques', 'ADJMP'),
#   ('.', 'YPFOR'),
#   ('"', 'PUNCT')],
#  [('Les', 'DET'),
#   ('soldats', 'NMP'),
#   ('pillent', 'VERB'),
#   ('les', 'DET'),
#   ('maisons', 'NFP'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('secrétaire', 'NMS'),
#   ('général', 'ADJMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('nations', 'NFP'),
#   ('Unies', 'ADJFP'),
#   (',', 'PUNCT'),
#   ('Ban', 'PROPN'),
#   ('ki-Moon', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('a', 'AUX'),
#   ('soulevé', 'VPPMS'),
#   ("d'", 'PREP'),
#   ('une', 'DINTFS'),
#   ('manière', 'NFS'),
#   ('claire', 'ADJFS'),
#   ('et', 'COCO'),
#   ('objective', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('dans', 'PREP'),
#   ('son', 'DET'),
#   ('rapport', 'NMS'),
#   ('publié', 'VPPMS'),
#   ('vendredi', 'NMS'),
#   ('et', 'COCO'),
#   ('qui', 'PREL'),
#   ('sera', 'AUX'),
#   ('examiné', 'VPPMS'),
#   ('mardi', 'NMS'),
#   ('prochain', 'ADJMS'),
#   ('par', 'PREP'),
#   ('le', 'DETMS'),
#   ('Conseil', 'NMS'),
#   ('de', 'PREP'),
#   ('sécurité', 'NFS'),
#   (',', 'PUNCT'),
#   ("l'", 'DET'),
#   ('urgence', 'NFS'),
#   ('de', 'PREP'),
#   ('faire', 'VERB'),
#   ('face', 'NFS'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('situation', 'NFS'),
#   ('relative', 'ADJFS'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('violations', 'NFP'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('droits', 'NMP'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('Homme', 'NMS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Sahara', 'PROPN'),
#   ('occidental', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('En', 'PREP'),
#   ('géométrie', 'NFS'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('dodécadodécaèdre', 'NMS'),
#   ('tronqué', 'VPPMS'),
#   ('est', 'AUX'),
#   ('un', 'DINTMS'),
#   ('polyèdre', 'NMS'),
#   ('uniforme', 'ADJMS'),
#   ('non-convexe', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('indexé', 'VPPMS'),
#   ('sous', 'PREP'),
#   ('le', 'DETMS'),
#   ('nom', 'NMS'),
#   ('U59', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Tout', 'ADV'),
#   ('en', 'PREP'),
#   ('regrettant', 'VERB'),
#   ('que', 'COSUB'),
#   ('le', 'DETMS'),
#   ('Conseil', 'NMS'),
#   ('de', 'PREP'),
#   ('sécurité', 'NFS'),
#   ('"', 'PUNCT'),
#   ("n'", 'ADV'),
#   ('assume', 'VERB'),
#   ('toujours', 'ADV'),
#   ('pas', 'ADV'),
#   ('ses', 'DET'),
#   ('responsabilités', 'NFP'),
#   ('face', 'NOUN'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('tragédie', 'NFS'),
#   ('syrienne', 'ADJFS'),
#   ('"', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('avec', 'PREP'),
#   ('notamment', 'ADV'),
#   ('le', 'DETMS'),
#   ('refus', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Russie', 'PROPN'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Chine', 'PROPN'),
#   ('de', 'PREP'),
#   ('voter', 'VERB'),
#   ('des', 'DET'),
#   ('sanctions', 'NFP'),
#   ('contre', 'PREP'),
#   ('Damas', 'PROPN'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('a', 'AUX'),
#   ('exclu', 'VPPMS'),
#   ('toute', 'DET'),
#   ('initiative', 'NFS'),
#   ('française', 'ADJFS'),
#   ('en', 'PREP'),
#   ('dehors', 'NOUN'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('cadre', 'NMS'),
#   ('légal', 'ADJMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('Nations', 'NFP'),
#   ('unies', 'ADJFP'),
#   ('.', 'YPFOR')],
#  [("C'", 'PDEMMS'),
#   ('est', 'AUX'),
#   ("l'", 'DET'),
#   ('une', 'PINDFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('trois', 'CHIF'),
#   ('banlieues', 'NFP'),
#   ('où', 'ADV'),
#   ('ce', 'PDEMMS'),
#   ('trafic', 'NMS'),
#   ('domine', 'VERB'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ("s'", 'PREF'),
#   ('est', 'AUX'),
#   ('donné', 'VPPMS'),
#   ("jusqu'", 'PREP'),
#   ('à', 'PREP'),
#   ('mi-août', 'NFS'),
#   ('pour', 'PREP'),
#   ('y', 'PPOBJFS'),
#   ('réfléchir', 'VERB'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('crée', 'VERB'),
#   ('alors', 'ADV'),
#   ('la', 'DETFS'),
#   ('vis', 'NFS'),
#   ('aérienne', 'ADJFS'),
#   ('(', 'PUNCT'),
#   ('ou', 'COCO'),
#   ('hélice', 'NFS'),
#   ('ou', 'COCO'),
#   ('aile', 'NFS'),
#   ('tournante', 'ADJFS'),
#   ('hélicoïde', 'ADJFS'),
#   ('...', 'PUNCT'),
#   (')', 'PUNCT'),
#   ('avec', 'PREP'),
#   ('une', 'DINTFS'),
#   ('simple', 'ADJFS'),
#   ('vis', 'NFS'),
#   ('passée', 'VPPFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('milieu', 'NMS'),
#   ('de', 'PREP'),
#   ('deux', 'CHIF'),
#   ('plaques', 'NFP'),
#   ('de', 'PREP'),
#   ('bois', 'NOUN'),
#   ('en', 'PREP'),
#   ("s'", 'PREF'),
#   ('inspirant', 'VERB'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('principe', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Vis', 'NFS'),
#   ("d'", 'PREP'),
#   ('Archimède', 'PROPN'),
#   (',', 'PUNCT'),
#   ('utilisée', 'VPPFS'),
#   ('dès', 'PREP'),
#   ("l'", 'DET'),
#   ('antiquité', 'NFS'),
#   ('pour', 'PREP'),
#   ('monter', 'VERB'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('eau', 'NFS'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('premiers', 'ADJMP'),
#   ('AVN', 'PROPN'),
#   ('Awards', 'XFAMIL'),
#   ('sont', 'AUX'),
#   ('décernés', 'VPPMP'),
#   ('en', 'PREP'),
#   ('février', 'NMS'),
#   ('1984', 'CHIF'),
#   (',', 'PUNCT'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('titre', 'NMS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('année', 'NFS'),
#   ('1983', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('À', 'PREP'),
#   ('partir', 'VERB'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('XXIe', 'ADJMS'),
#   ('siècle', 'NMS'),
#   (',', 'PUNCT'),
#   ('les', 'DET'),
#   ('recensements', 'NMP'),
#   ('réels', 'ADJMP'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('communes', 'NFP'),
#   ('de', 'PREP'),
#   ('moins', 'ADV'),
#   ('de', 'PREP'),
#   ('10 000', 'CHIF'),
#   ('habitants', 'NMP'),
#   ('ont', 'VERB'),
#   ('lieu', 'NMS'),
#   ('tous', 'ADJMP'),
#   ('les', 'DET'),
#   ('cinq', 'CHIF'),
#   ('ans', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('en', 'PPOBJMS'),
#   ('fut', 'VERB'),
#   ('comme', 'COSUB'),
#   ('de', 'PREP'),
#   ('tout', 'ADJMS'),
#   ('ce', 'PDEMMS'),
#   ("qu'", 'PREL'),
#   ('il', 'PPER3MS'),
#   ('avait', 'AUX'),
#   ('fait', 'VPPMS'),
#   ("jusqu'", 'PREP'),
#   ('alors', 'ADV'),
#   (':', 'PUNCT'),
#   ('les', 'DET'),
#   ('uns', 'PINDMP'),
#   ("s'", 'PREF'),
#   ('en', 'PPOBJMP'),
#   ('édifièrent', 'VERB'),
#   (',', 'PUNCT'),
#   ('les', 'DET'),
#   ('autres', 'PRON'),
#   ("s'", 'PREF'),
#   ('en', 'PPOBJMP'),
#   ('scandalisèrent', 'VERB'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('équipe', 'NFS'),
#   ('la', 'DETFS'),
#   ('mieux', 'ADV'),
#   ('classée', 'ADJFS'),
#   ('dispute', 'VERB'),
#   ('le', 'DETMS'),
#   ('premier', 'ADJMS'),
#   ('match', 'NMS'),
#   ('à', 'PREP'),
#   ('domicile', 'NMS'),
#   ('puis', 'ADV'),
#   ('se', 'PREF'),
#   ('déplace', 'VERB'),
#   ('chez', 'PREP'),
#   ('son', 'DET'),
#   ('adversaire', 'NMS'),
#   ('lors', 'ADV'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('seconde', 'ADJFS'),
#   ('rencontre', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Louise', 'PROPN'),
#   ('de', 'PREP'),
#   ('Bretagne', 'XFAMIL'),
#   ('a', 'AUX'),
#   ('alors', 'ADV'),
#   ('assuré', 'VPPMS'),
#   ("l'", 'DET'),
#   ('éducation', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('quatre', 'CHIF'),
#   ('enfants', 'NOUN'),
#   ('de', 'PREP'),
#   ('Gui', 'PROPN'),
#   ('II', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Cette', 'PDEMFS'),
#   ('tour', 'NFS'),
#   ('de', 'PREP'),
#   ('48', 'CHIF'),
#   ('m', 'NMP'),
#   ('a', 'AUX'),
#   ('été', 'AUX'),
#   ('achevée', 'VPPFS'),
#   ('en', 'PREP'),
#   ('1962', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('On', 'PINDMS'),
#   ('en', 'PPOBJMS'),
#   ('retrouve', 'VERB'),
#   ('aussi', 'ADV'),
#   ('un', 'DINTMS'),
#   ('peu', 'ADV'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Canada', 'PROPN'),
#   ('et', 'COCO'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('États-Unis', 'PROPN'),
#   (',', 'PUNCT'),
#   ('comme', 'COSUB'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Nouveau-Brunswick', 'PROPN'),
#   ('et', 'COCO'),
#   ('dans', 'PREP'),
#   ("l'", 'DET'),
#   ('Est', 'NMS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('Ontario', 'PROPN'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('dans', 'PREP'),
#   ('le', 'DETMS'),
#   ('Nord', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Nouvelle-Angleterre', 'PROPN'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ('New-York', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('ne', 'ADV'),
#   ('se', 'PREF'),
#   ('représenta', 'VERB'),
#   ('pas', 'ADV'),
#   ('en', 'PREP'),
#   ('1972', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('coopératives', 'NFP'),
#   ('ne', 'ADV'),
#   ('sont', 'AUX'),
#   ('pas', 'ADV'),
#   ('de', 'PREP'),
#   ('gauche', 'NFS'),
#   ('ou', 'COCO'),
#   ('de', 'PREP'),
#   ('droite', 'NFS'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ("s'", 'PREF'),
#   ('agit', 'VERB'),
#   ('seulement', 'ADV'),
#   ('de', 'PREP'),
#   ('logements', 'NMP'),
#   ('gérés', 'VPPMP'),
#   ('par', 'PREP'),
#   ('les', 'DET'),
#   ('gens', 'NOUN'),
#   ('dont', 'PREL'),
#   ('le', 'DETMS'),
#   ('but', 'NMS'),
#   ("n'", 'ADV'),
#   ('est', 'VERB'),
#   ('pas', 'ADV'),
#   ('de', 'PREP'),
#   ('faire', 'VERB'),
#   ('du', 'DINTMS'),
#   ('profit', 'NMS'),
#   ('mais', 'COCO'),
#   ("d'", 'PREP'),
#   ('habiter', 'VERB'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('titre', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('jeu', 'NMS'),
#   ('est', 'AUX'),
#   ('une', 'DINTFS'),
#   ('référence', 'NFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('film', 'NMS'),
#   ('Clash', 'MOTINC'),
#   ('of', 'MOTINC'),
#   ('the', 'MOTINC'),
#   ('Titans', 'MOTINC'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('la', 'DETFS'),
#   ('majorité', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('noms', 'NMP'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('niveaux', 'NMP'),
#   ('comprennent', 'VERB'),
#   ('des', 'DET'),
#   ('références', 'NFP'),
#   ('cinématographiques', 'ADJFP'),
#   ('.', 'YPFOR')],
#  [('Cependant', 'ADV'),
#   (',', 'PUNCT'),
#   ("n'", 'ADV'),
#   ('y', 'PPOBJFP'),
#   ('a', 'VERB'),
#   ('-t', 'PART'),
#   ('-il', 'PPER3MS'),
#   ('pas', 'ADV'),
#   ('là', 'ADV'),
#   ('un', 'DINTMS'),
#   ('contresens', 'NMS'),
#   ('complet', 'ADJMS'),
#   ('?', 'PUNCT')],
#  [('Pour', 'PREP'),
#   ('ce', 'PRON'),
#   ('qui', 'PREL'),
#   ('est', 'AUX'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('printemps', 'NMS'),
#   ('arabe', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('nous', 'PREFP'),
#   ('avons', 'AUX'),
#   ('insisté', 'VPPMS'),
#   ('avec', 'PREP'),
#   ("l'", 'DET'),
#   ('UE', 'PROPN'),
#   ('pour', 'PREP'),
#   ('soutenir', 'VERB'),
#   ('dans', 'PREP'),
#   ('le', 'DETMS'),
#   ('cadre', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('nouvelle', 'ADJFS'),
#   ('politique', 'NFS'),
#   ('de', 'PREP'),
#   ('voisinage', 'NMS'),
#   ('européenne', 'ADJFS'),
#   ('la', 'DETFS'),
#   ('réalisation', 'NFS'),
#   ("d'", 'PREP'),
#   ('une', 'DINTFS'),
#   ('intégration', 'NFS'),
#   ('économique', 'ADJFS'),
#   ('avec', 'PREP'),
#   ('les', 'DET'),
#   ('pays', 'NMP'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('Afrique', 'PROPN'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('nord', 'NMS'),
#   ('"', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('deux', 'CHIF'),
#   ('barmans', 'NMP'),
#   ('salariés', 'ADJMP'),
#   (',', 'PUNCT'),
#   ('sans', 'PREP'),
#   ('aucun', 'DET'),
#   ('sourire', 'NMS'),
#   (',', 'PUNCT'),
#   ('passent', 'VERB'),
#   ('leur', 'DET'),
#   ('temps', 'NMS'),
#   ('à', 'PREP'),
#   ('rincer', 'VERB'),
#   ('la', 'DETFS'),
#   ('vaisselle', 'NFS'),
#   ('sans', 'PREP'),
#   ('mettre', 'VERB'),
#   ('une', 'DINTFS'),
#   ('quelconque', 'ADJFS'),
#   ('ambiance', 'NFS'),
#   ('dans', 'PREP'),
#   ('ce', 'PDEMMS'),
#   ('bar', 'NMS'),
#   ('où', 'ADV'),
#   ('la', 'DETFS'),
#   ('musique', 'NFS'),
#   ('domine', 'VERB'),
#   ('avec', 'PREP'),
#   ('force', 'NFS'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('propreté', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('toilettes', 'NFP'),
#   ('est', 'AUX'),
#   ('toujours', 'ADV'),
#   ('impeccable', 'ADJFS'),
#   ('.', 'YPFOR')],
#  [('Selon', 'PREP'),
#   ('la', 'DETFS'),
#   ('tradition', 'NFS'),
#   ('religieuse', 'ADJFS'),
#   ('chinoise', 'ADJFS'),
#   ('où', 'ADV'),
#   ('la', 'DETFS'),
#   ('généalogie', 'NFS'),
#   ('prime', 'VERB'),
#   ('sur', 'PREP'),
#   ("l'", 'DET'),
#   ('idéologie', 'NFS'),
#   ('pour', 'PREP'),
#   ('la', 'DETFS'),
#   ('détermination', 'NFS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('dénomination', 'NFS'),
#   (',', 'PUNCT'),
#   ('tout', 'DET'),
#   ('abbé', 'NMS'),
#   ('qui', 'PREL'),
#   ('peut', 'VERB'),
#   ('faire', 'AUX'),
#   ('remonter', 'VERB'),
#   ('sa', 'DET'),
#   ('lignée', 'NFS'),
#   ('à', 'PREP'),
#   ('un', 'DINTMS'),
#   ('maître', 'NMS'),
#   ('Chan', 'PROPN'),
#   (',', 'PUNCT'),
#   ('quelle', 'ADJFS'),
#   ('que', 'COSUB'),
#   ('soit', 'AUX'),
#   ('la', 'DETFS'),
#   ('nature', 'NFS'),
#   ('de', 'PREP'),
#   ('ses', 'DET'),
#   ('pratiques', 'NFP'),
#   (',', 'PUNCT'),
#   ('est', 'AUX'),
#   ('en', 'PREP'),
#   ('droit', 'NMS'),
#   ('de', 'PREP'),
#   ('se', 'PREF'),
#   ('réclamer', 'VERB'),
#   ('de', 'PREP'),
#   ('ce', 'PDEMMS'),
#   ('courant', 'NMS'),
#   (',', 'PUNCT'),
#   ('où', 'ADV'),
#   ('dominent', 'VERB'),
#   ('après', 'PREP'),
#   ('846', 'CHIF'),
#   ('deux', 'CHIF'),
#   ('branches', 'NFP'),
#   (':', 'PUNCT'),
#   ('Linji', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('临济', 'PROPN'),
#   (')', 'PUNCT'),
#   ('qui', 'PREL'),
#   ('remonte', 'VERB'),
#   ('à', 'PREP'),
#   ('Línjì', 'PROPN'),
#   ('Yìxuán', 'XFAMIL'),
#   ('临济', 'PROPN'),
#   ('义', 'XFAMIL'),
#   ('玄', 'XFAMIL'),
#   ('(', 'PUNCT'),
#   ('?', 'PUNCT'),
#   ('-', 'PUNCT'),
#   ('869', 'CHIF'),
#   (')', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('recensement', 'NMS'),
#   ('de', 'PREP'),
#   ('1991', 'CHIF'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('comptait', 'VERB'),
#   ('55', 'CHIF'),
#   ('habitants', 'NMP'),
#   (',', 'PUNCT'),
#   ('tous', 'ADJMP'),
#   ('serbes', 'ADJMP'),
#   ('.', 'YPFOR')],
#  [('Certaines', 'DET'),
#   ('personnes', 'NFP'),
#   ('sont', 'AUX'),
#   ('battues', 'VPPFP'),
#   ('et', 'COCO'),
#   ('il', 'PPER3MS'),
#   ('y', 'PPOBJMS'),
#   ('a', 'VERB'),
#   ('de', 'DET'),
#   ('nombreuses', 'ADJFP'),
#   ('arrestations', 'NFP'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('Yougoslavie', 'PROPN'),
#   ("n'", 'ADV'),
#   ('a', 'AUX'),
#   ('pas', 'ADV'),
#   ('entretenu', 'VPPMS'),
#   ('de', 'DET'),
#   ('relations', 'NFP'),
#   ('diplomatiques', 'ADJFP'),
#   ('avec', 'PREP'),
#   ('des', 'DET'),
#   ('pays', 'NMP'),
#   ('comme', 'PREP'),
#   ('le', 'DETMS'),
#   ('Portugal', 'PROPN'),
#   ("jusqu'", 'PREP'),
#   ('en', 'PREP'),
#   ('1974', 'CHIF'),
#   (',', 'PUNCT'),
#   ("l'", 'DET'),
#   ('Espagne', 'PROPN'),
#   ("jusqu'", 'PREP'),
#   ('en', 'PREP'),
#   ('1975', 'CHIF'),
#   ('ou', 'COCO'),
#   ("l'", 'DET'),
#   ('Afrique', 'PROPN'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Sud', 'NMS'),
#   ('à', 'PREP'),
#   ('cause', 'NFS'),
#   ('de', 'PREP'),
#   ('son', 'DET'),
#   ('régime', 'NMS'),
#   ("d'", 'PREP'),
#   ('apartheid', 'NMS'),
#   ('.', 'YPFOR')],
#  [('APEX', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('acronyme', 'NMS'),
#   ('de', 'PREP'),
#   ('«', 'PUNCT'),
#   ('Additive', 'MOTINC'),
#   ('system', 'MOTINC'),
#   ('of', 'MOTINC'),
#   ('Photography', 'MOTINC'),
#   ('EXposure', 'MOTINC'),
#   ('»', 'PUNCT'),
#   (')', 'PUNCT'),
#   ('est', 'AUX'),
#   ('une', 'DINTFS'),
#   ('méthode', 'NFS'),
#   ('de', 'PREP'),
#   ('calcul', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('temps', 'NMS'),
#   ("d'", 'PREP'),
#   ('exposition', 'NFS'),
#   ('basée', 'VPPFS'),
#   ('sur', 'PREP'),
#   ('une', 'DINTFS'),
#   ('mesure', 'NFS'),
#   ('en', 'PREP'),
#   ('Ev', 'MOTINC'),
#   ('(', 'PUNCT'),
#   ('Exposure', 'MOTINC'),
#   ('value', 'MOTINC'),
#   (')', 'PUNCT'),
#   ('adoptée', 'VPPFS'),
#   ('par', 'PREP'),
#   ('la', 'DETFS'),
#   ('plupart', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('posemètres', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Bien', 'ADV'),
#   ("qu'", 'COSUB'),
#   ('ils', 'PPER3MP'),
#   ('cultivent', 'VERB'),
#   ("l'", 'DET'),
#   ('art', 'NMS'),
#   ('de', 'PREP'),
#   ('disparaître', 'VERB'),
#   ('derrière', 'PREP'),
#   ('les', 'DET'),
#   ('auteurs', 'NMP'),
#   ("qu'", 'PREL'),
#   ('ils', 'PPER3MP'),
#   ('défendent', 'VERB'),
#   (',', 'PUNCT'),
#   ('les', 'DET'),
#   ('éditeurs', 'PROPN'),
#   ('ont', 'VERB'),
#   ('une', 'DINTFS'),
#   ('histoire', 'NFS'),
#   ('parfois', 'ADV'),
#   ('aussi', 'ADV'),
#   ('palpitante', 'ADJFS'),
#   ('que', 'COSUB'),
#   ('celle', 'PDEMFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('personnages', 'NMP'),
#   ('de', 'PREP'),
#   ('roman', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Puis', 'ADV'),
#   ('elle', 'PPER3FS'),
#   ('se', 'PREF'),
#   ('repose', 'VERB'),
#   ('en', 'PREP'),
#   ('Calabre', 'PROPN'),
#   ('pendant', 'PREP'),
#   ('le', 'DETMS'),
#   ('reste', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('mois', 'NMS'),
#   ("d'", 'PREP'),
#   ('août', 'NMS'),
#   ('et', 'COCO'),
#   ('en', 'PREP'),
#   ('début', 'NMS'),
#   ('de', 'PREP'),
#   ('septembre', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Criton', 'PROPN'),
#   ('sait', 'VERB'),
#   ('que', 'COSUB'),
#   ('Socrate', 'PROPN'),
#   ('est', 'AUX'),
#   ('aussi', 'ADV'),
#   ('fidèle', 'ADJ'),
#   ('que', 'COSUB'),
#   ('lui', 'PPOBJMS'),
#   ('et', 'COCO'),
#   ('il', 'PPER3MS'),
#   ('pense', 'VERB'),
#   ('que', 'COSUB'),
#   ('si', 'COSUB'),
#   ('Socrate', 'PROPN'),
#   ('ne', 'ADV'),
#   ('se', 'PREF'),
#   ('sauve', 'VERB'),
#   ('pas', 'ADV'),
#   ('pour', 'PREP'),
#   ('lui-même', 'PPOBJMS'),
#   (',', 'PUNCT'),
#   ('peut-être', 'ADV'),
#   ('se', 'PREF'),
#   ('sauvera', 'VERB'),
#   ('-t', 'PART'),
#   ('-il', 'PPER3MS'),
#   ('pour', 'PREP'),
#   ('ses', 'DET'),
#   ('amis', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('tenant', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('titre', 'NMS'),
#   (',', 'PUNCT'),
#   ('Manchester', 'PROPN'),
#   ('United', 'XFAMIL'),
#   ('conserve', 'VERB'),
#   ('son', 'DET'),
#   ('trophée', 'NMS'),
#   ('en', 'PREP'),
#   ('battant', 'VERB'),
#   ('Aston', 'PROPN'),
#   ('Villa', 'XFAMIL'),
#   ('sur', 'PREP'),
#   ('le', 'DETMS'),
#   ('score', 'NMS'),
#   ('de', 'PREP'),
#   ('2', 'CHIF'),
#   ('buts', 'NMP'),
#   ('à', 'PREP'),
#   ('1', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Lors', 'ADV'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('tour', 'NMS'),
#   ('final', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('club', 'NMS'),
#   ('termina', 'VERB'),
#   ('2', 'CHIF'),
#   ('derrière', 'PREP'),
#   ('le', 'DETMS'),
#   ('VfB', 'PROPN'),
#   ('Speldorf', 'XFAMIL'),
#   ('et', 'COCO'),
#   ('monta', 'VERB'),
#   ('en', 'PREP'),
#   ('2', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Khaled', 'PROPN'),
#   ('Hadadah', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('secrétaire', 'NMS'),
#   ('général', 'ADJMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Parti', 'NMS'),
#   ('communiste', 'ADJMS'),
#   ('libanais', 'ADJ'),
#   (',', 'PUNCT'),
#   ("s'", 'PREF'),
#   ('est', 'AUX'),
#   ('dit', 'VPPMS'),
#   ('favorable', 'ADJ'),
#   ('à', 'PREP'),
#   ('un', 'DINTMS'),
#   ('soulèvement', 'NMS'),
#   ('arabe', 'ADJMS'),
#   ('de', 'PREP'),
#   ('solidarité', 'NFS'),
#   ('avec', 'PREP'),
#   ('ce', 'PDEMMS'),
#   ('réveil', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Monde', 'NMS'),
#   ('arabe', 'ADJMS'),
# ...
#   ('cloche', 'NFS'),
#   ('datée', 'VPPFS'),
#   ('de', 'PREP'),
#   ('1660', 'CHIF'),
#   ('qui', 'PREL'),
#   ('provient', 'VERB'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('collège', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('oratoriens', 'NMP'),
#   ('de', 'PREP'),
#   ('Thuin', 'PROPN'),
#   ('en', 'PREP'),
#   ('Belgique', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ('cultive', 'VERB'),
#   ("d'", 'PREP'),
#   ('ailleurs', 'ADV'),
#   ('cette', 'PDEMFS'),
#   ('ambiguïté', 'NFS'),
#   ('sur', 'PREP'),
#   ('elle', 'PPER3FS'),
#   ("puisqu'", 'COSUB'),
#   ('elle', 'PPER3FS'),
#   ('possède', 'VERB'),
#   ('deux', 'CHIF'),
#   ('tatouages', 'NMP'),
#   (':', 'PUNCT'),
#   ('un', 'PINDMS'),
#   ('représentant', 'VERB'),
#   ('le', 'DETMS'),
#   ('Aum', 'PROPN'),
#   ('et', 'COCO'),
#   ('un', 'DINTMS'),
#   ('autre', 'ADJMS'),
#   ('représentant', 'VERB'),
#   ('le', 'DETMS'),
#   ('démon', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Sa', 'DET'),
#   ('femme', 'NFS'),
#   ('le', 'PPOBJMS'),
#   ('trompa', 'VERB'),
#   ('régulièrement', 'ADV'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('étymologie', 'NFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('onm', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('commune', 'NFS'),
#   ('fait', 'VERB'),
#   ('référence', 'NFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('mot', 'NMS'),
#   ('slave', 'ADJMS'),
#   ('vlk', 'NOUN'),
#   ('sigifiant', 'VERB'),
#   ('loup', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Jos', 'PROPN'),
#   ('Van', 'XFAMIL'),
#   ('Assche', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('né', 'VPPMS'),
#   ('le', 'DETMS'),
#   ('12', 'CHIF'),
#   ('février', 'NMS'),
#   ('1950', 'CHIF'),
#   ('à', 'PREP'),
#   ('Louvain', 'PROPN'),
#   ('est', 'AUX'),
#   ('un', 'DINTMS'),
#   ('homme', 'NMS'),
#   ('politique', 'ADJMS'),
#   ('belge', 'ADJMS'),
#   ('bruxellois', 'ADJ'),
#   (',', 'PUNCT'),
#   ('ex-membre', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Vlaams', 'PROPN'),
#   ('Belang', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [('Refusant', 'VERB'),
#   ('tout', 'DET'),
#   ('contact', 'NMS'),
#   ('avec', 'PREP'),
#   ('le', 'DETMS'),
#   ('monde', 'NMS'),
#   ('extérieur', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('ils', 'PPER3MP'),
#   ('constituent', 'VERB'),
#   ("l'", 'DET'),
#   ('un', 'PINDMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('derniers', 'ADJMP'),
#   ('peuples', 'NMP'),
#   ('coupés', 'VPPMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('monde', 'NMS'),
#   (',', 'PUNCT'),
#   ('vivant', 'VERB'),
#   ('en', 'PREP'),
#   ('autarcie', 'NFS'),
#   ('dans', 'PREP'),
#   ('des', 'DET'),
#   ('conditions', 'NFP'),
#   ("n'", 'ADV'),
#   ('ayant', 'AUX'),
#   ('pas', 'ADV'),
#   ('changé', 'VPPMS'),
#   ('depuis', 'PREP'),
#   ('des', 'DET'),
#   ('milliers', 'NMP'),
#   ("d'", 'PREP'),
#   ('années', 'NFP'),
#   ('.', 'YPFOR')],
#  [('Tant', 'ADV'),
#   ('que', 'COSUB'),
#   ('nous', 'PREFP'),
#   ("n'", 'ADV'),
#   ('aurons', 'AUX'),
#   ('pas', 'ADV'),
#   ('pu', 'VPPMS'),
#   ('reconnaître', 'VERB'),
#   ('cette', 'PDEMFS'),
#   ('faute', 'NFS'),
#   ('-là', 'ADV'),
#   (',', 'PUNCT'),
#   ('toute', 'DET'),
#   ('tentative', 'NFS'),
#   ('vers', 'PREP'),
#   ('un', 'DINTMS'),
#   ('quelconque', 'ADJMS'),
#   ('accord', 'NMS'),
#   ('sera', 'AUX'),
#   ('illusoire', 'ADJFS'),
#   ('et', 'COCO'),
#   ("d'", 'PREP'),
#   ('office', 'NMS'),
#   ('promise', 'VPPFS'),
#   ('à', 'PREP'),
#   ('un', 'DINTMS'),
#   ('nouvel', 'ADJMS'),
#   ('échec', 'NMS'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('Coupe', 'NFS'),
#   ('Intertoto', 'PROPN'),
#   ('1995', 'CHIF'),
#   ('est', 'AUX'),
#   ('la', 'DETFS'),
#   ('première', 'ADJFS'),
#   ('édition', 'NFS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Coupe', 'NFS'),
#   ('Intertoto', 'PROPN'),
#   ('organisée', 'VPPFS'),
#   ('par', 'PREP'),
#   ("l'", 'DET'),
#   ('Union', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('associations', 'NFP'),
#   ('européennes', 'ADJFP'),
#   ('de', 'PREP'),
#   ('football', 'NMS'),
#   ('(', 'PUNCT'),
#   ('UEFA', 'PROPN'),
#   (')', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ("s'", 'PREF'),
#   ('attarde', 'VERB'),
#   ('sur', 'PREP'),
#   ('le', 'DETMS'),
#   ('pendant', 'NMS'),
#   ('social', 'ADJMS'),
#   (':', 'PUNCT'),
#   ('adaptation', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('formations', 'NFP'),
#   ('professionnelles', 'ADJFP'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('enjeux', 'NMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('durable', 'NMS'),
#   (',', 'PUNCT'),
#   ('emplois', 'NMP'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('personnes', 'NFP'),
#   ('en', 'PREP'),
#   ('situation', 'NFS'),
#   ('de', 'PREP'),
#   ('handicaps', 'NMP'),
#   (',', 'PUNCT'),
#   ('lutte', 'NFS'),
#   ('contre', 'PREP'),
#   ('le', 'DETMS'),
#   ('décrochage', 'NMS'),
#   ('scolaire', 'ADJMS'),
#   ('précoce', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('développement', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('financement', 'NMS'),
#   ('privé', 'ADJMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('recherche', 'NFS'),
#   ('dont', 'PREL'),
#   ('le', 'DETMS'),
#   ('budget', 'NMS'),
#   ('devrait', 'VERB'),
#   ('être', 'AUX'),
#   ('revu', 'VPPMS'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('hausse', 'NFS'),
#   ('(', 'PUNCT'),
#   ('3', 'CHIF'),
#   ('%', 'SYM'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('PIB', 'NMS'),
#   ('dès', 'PREP'),
#   ('2010', 'CHIF'),
#   (')', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('lance', 'VERB'),
#   ('également', 'ADV'),
#   ('une', 'DINTFS'),
#   ('collection', 'NFS'),
#   ('pour', 'PREP'),
#   ('homme', 'NMS'),
#   (':', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('retravaille', 'VERB'),
#   ('le', 'DETMS'),
#   ('classique', 'NMS'),
#   ('masculin', 'ADJMS'),
#   ('et', 'COCO'),
#   ('lui', 'PPOBJMS'),
#   ('donne', 'VERB'),
#   ('un', 'DINTMS'),
#   ('style', 'NMS'),
#   ('résolument', 'ADV'),
#   ('moderne', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('Espace', 'NMS'),
#   ('éthique', 'ADJMS'),
#   ('/', 'SYM'),
#   ('AP-HP', 'PROPN'),
#   ('propose', 'VERB'),
#   ('des', 'DET'),
#   ('formations', 'NFP'),
#   ('en', 'PREP'),
#   ('vue', 'NFS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('obtention', 'NFS'),
#   ("d'", 'PREP'),
#   ('un', 'DINTMS'),
#   ('diplôme', 'NMS'),
#   ('accessible', 'ADJMS'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('ensemble', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('professionnels', 'NMP'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('santé', 'NFS'),
#   (',', 'PUNCT'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('membres', 'NMP'),
#   ("d'", 'PREP'),
#   ('associations', 'NFP'),
#   ('à', 'PREP'),
#   ('caractère', 'NMS'),
#   ('médico-social', 'ADJMS'),
#   ('et', 'COCO'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('étudiants', 'NMP'),
#   ('en', 'PREP'),
#   ('formation', 'NFS'),
#   (':', 'PUNCT')],
#  [('À', 'PREP'),
#   ("l'", 'DET'),
#   ('hôpital', 'NMS'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('a', 'AUX'),
#   ('avoué', 'VPPMS'),
#   ('le', 'DETMS'),
#   ('meurtre', 'NMS'),
#   ('et', 'COCO'),
#   ('a', 'AUX'),
#   ('demandé', 'VPPMS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('personnel', 'NMS'),
#   ('infirmier', 'ADJMS'),
#   ("qu'", 'COSUB'),
#   ('il', 'PPER3MS'),
#   ('soit', 'AUX'),
#   ('transféré', 'VPPMS'),
#   ('dans', 'PREP'),
#   ('un', 'DINTMS'),
#   ('pénitencier', 'NMS'),
#   ('.', 'YPFOR')],
#  [('En', 'PREP'),
#   ('1995', 'CHIF'),
#   (',', 'PUNCT'),
#   ('David', 'PROPN'),
#   ('Miscavige', 'XFAMIL'),
#   ('a', 'AUX'),
#   ('initié', 'VPPMS'),
#   ('le', 'DETMS'),
#   ('développement', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('programme', 'NMS'),
#   ('«', 'PUNCT'),
#   ("l'", 'DET'),
#   ('Age', 'NMS'),
#   ("d'", 'PREP'),
#   ('Or', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Tech', 'NFS'),
#   ('»', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('un', 'DINTMS'),
#   ('nouveau', 'ADJMS'),
#   ('concept', 'NMS'),
#   ("d'", 'PREP'),
#   ('entraînement', 'NMS'),
#   ('pour', 'PREP'),
#   ('les', 'DET'),
#   ('auditeurs', 'NMP'),
#   ('scientologues', 'ADJMP'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('est', 'AUX'),
#   ('exilé', 'VPPMS'),
#   ('et', 'COCO'),
#   ('meurt', 'VERB'),
#   ('dans', 'PREP'),
#   ("l'", 'DET'),
#   ('obscurité', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('mineurs', 'NMP'),
#   (',', 'PUNCT'),
#   ('pris', 'VERB'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('piège', 'NMS'),
#   ('à', 'PREP'),
#   ('688', 'CHIF'),
#   ('mètres', 'NMP'),
#   ('de', 'PREP'),
#   ('profondeur', 'NFS'),
#   ('et', 'COCO'),
#   ('à', 'PREP'),
#   ('environ', 'ADV'),
#   ('5', 'CHIF'),
#   ('km', 'NMP'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('entrée', 'NFS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('mine', 'NFS'),
#   (',', 'PUNCT'),
#   ('se', 'PREF'),
#   ('sont', 'AUX'),
#   ('installés', 'VPPMP'),
#   ('dans', 'PREP'),
#   ('un', 'DINTMS'),
#   ('refuge', 'NMS'),
#   ('de', 'PREP'),
#   ('sécurité', 'NFS'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('agitateur', 'NMS'),
#   ('de', 'PREP'),
#   ('Parr', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('Parr', 'PROPN'),
#   ('shaker', 'NMS'),
#   (')', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('premier', 'ADJMS'),
#   ('appareil', 'NMS'),
#   ('permettant', 'VERB'),
#   ("l'", 'DET'),
#   ('hydrogénation', 'NFS'),
#   ('à', 'PREP'),
#   ('hautes', 'ADJFP'),
#   ('température', 'NFS'),
#   ('et', 'COCO'),
#   ('pression', 'NFS'),
#   (',', 'PUNCT'),
#   ('basé', 'VPPMS'),
#   ('sur', 'PREP'),
#   ('les', 'DET'),
#   ('travaux', 'NMP'),
#   ('de', 'PREP'),
#   ('Voorhees', 'PROPN'),
#   ('et', 'COCO'),
#   ('Adams', 'PROPN'),
#   (',', 'PUNCT'),
#   ('a', 'AUX'),
#   ('été', 'AUX'),
#   ('commercialisé', 'VPPMS'),
#   ('en', 'PREP'),
#   ('1926', 'CHIF'),
#   ('et', 'COCO'),
#   ('reste', 'VERB'),
#   ("d'", 'PREP'),
#   ('usage', 'NMS'),
#   ('courant', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('"', 'PUNCT'),
#   ('Les', 'DET'),
#   ('dimanches', 'NMP'),
#   ('et', 'COCO'),
#   ('jours', 'NMP'),
#   ('fériés', 'ADJMP'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ("n'", 'ADV'),
#   ('y', 'PPOBJMS'),
#   ('a', 'VERB'),
#   ('pas', 'ADV'),
#   ('de', 'DET'),
#   ('cars', 'NMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('tout', 'PINDMS'),
#   (',', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ("s'", 'PREF'),
#   ('est', 'AUX'),
#   ('plaint', 'VPPMS'),
#   ('une', 'DINTFS'),
#   ('habitante', 'NFS'),
#   ('.', 'YPFOR')],
#  [('NVE', 'PROPN'),
#   ('demande', 'VERB'),
#   ('ainsi', 'ADV'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('propriétaires', 'NMP'),
#   ('de', 'PREP'),
#   ('puits', 'NOUN'),
#   ('et', 'COCO'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('autorités', 'NFP'),
#   ('compétentes', 'ADJFP'),
#   ('de', 'PREP'),
#   ('surveiller', 'VERB'),
#   ('les', 'DET'),
#   ('niveaux', 'NMP'),
#   ("d'", 'PREP'),
#   ('eau', 'NFS'),
#   ('de', 'PREP'),
#   ('leurs', 'DET'),
#   ('ouvrages', 'NMP'),
#   ('.', 'YPFOR')],
#  [('En', 'PREP'),
#   ('966', 'CHIF'),
#   (',', 'PUNCT'),
#   ('elle', 'PPER3FS'),
#   ('donne', 'VERB'),
#   ('naissance', 'NFS'),
#   ('à', 'PREP'),
#   ('un', 'DINTMS'),
#   ('fils', 'NMS'),
#   (',', 'PUNCT'),
#   ('nommé', 'VPPMS'),
#   ('Edmond', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Si', 'COSUB'),
#   ('vous', 'PREFP'),
#   ('voulez', 'VERB'),
#   ('un', 'DINTMS'),
#   ('établissement', 'NMS'),
#   ('où', 'ADV'),
#   ('la', 'DETFS'),
#   ('serveuse', 'NFS'),
#   ('change', 'VERB'),
#   ('son', 'DET'),
#   ('petit', 'NMS'),
#   ('à', 'PREP'),
#   ('même', 'ADV'),
#   ('une', 'DINTFS'),
#   ('banquette', 'NFS'),
#   (',', 'PUNCT'),
#   ('où', 'ADV'),
#   ('la', 'DETFS'),
#   ('boisson', 'NFS'),
#   ("n'", 'ADV'),
#   ('est', 'AUX'),
#   ('pas', 'ADV'),
#   ('servie', 'VPPFS'),
#   ('dans', 'PREP'),
#   ('sa', 'DET'),
#   ('bouteille', 'NFS'),
#   ("d'", 'PREP'),
#   ('origine', 'NFS'),
#   ('(', 'PUNCT'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ('piètre', 'ADJFS'),
#   ('fraîcheur', 'NFS'),
#   (')', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('les', 'DET'),
#   ('pizzas', 'NFP'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('limite', 'NFS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('indigeste', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('vous', 'PREFP'),
#   ('allez', 'VERB'),
#   ('être', 'AUX'),
#   ('servi', 'VPPMS'),
#   ('!', 'PUNCT')],
#  [('Léopold', 'PROPN'),
#   ('Georges', 'XFAMIL'),
#   ('Pelletier', 'XFAMIL'),
#   ('est', 'AUX'),
#   ('un', 'PINDMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('premiers', 'ADJMP'),
#   ('pasteurs', 'NMP'),
#   ('piétistes', 'ADJMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Ban', 'PROPN'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Roche', 'PROPN'),
#   (',', 'PUNCT'),
#   ('prédécesseur', 'NMS'),
#   ('(', 'PUNCT'),
#   ('de', 'PREP'),
#   ('1707', 'CHIF'),
#   ('à', 'PREP'),
#   ('1712', 'CHIF'),
#   (')', 'PUNCT'),
#   ('de', 'PREP'),
#   ('Jean', 'PROPN'),
#   ('Georges', 'XFAMIL'),
#   ('Stuber', 'XFAMIL'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ('Jean-Frédéric', 'PROPN'),
#   ('Oberlin', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('un', 'PINDMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('grands', 'ADJMP'),
#   ('chocs', 'NMP'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('saison', 'NFS'),
#   ('fut', 'AUX'),
#   ('le', 'DETMS'),
#   ('match', 'NMS'),
#   ('Amnéville-Thionville', 'PROPN'),
#   ('qui', 'PREL'),
#   ('se', 'PREF'),
#   ('joua', 'VERB'),
#   ('devant', 'PREP'),
#   ('plus', 'ADV'),
#   ('de', 'PREP'),
#   ('4000', 'CHIF'),
#   ('spectateurs', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Merci', 'INTJ'),
#   ('pour', 'PREP'),
#   ("l'", 'DET'),
#   ('aide', 'NFS'),
#   ('que', 'PREL'),
#   ('vous', 'PREFP'),
#   ('apportez', 'VERB'),
#   ('.', 'YPFOR')],
#  [('Ce', 'PDEMMS'),
#   ("n'", 'ADV'),
#   ('est', 'AUX'),
#   ('pas', 'ADV'),
#   ('un', 'DINTMS'),
#   ('résultat', 'NMS'),
#   ('satisfaisant', 'ADJMS'),
#   ('car', 'COCO'),
#   ('il', 'PPER3MS'),
#   ('est', 'AUX'),
#   ('expérimentalement', 'ADV'),
#   ('établi', 'VPPMS'),
#   ('que', 'COSUB'),
#   ('plus', 'ADV'),
#   ('on', 'PINDMS'),
#   ('comprime', 'VERB'),
#   ('un', 'DINTMS'),
#   ('solide', 'NMS'),
#   (',', 'PUNCT'),
#   ('plus', 'ADV'),
#   ('il', 'PPER3MS'),
#   ('devient', 'VERB'),
#   ('difficile', 'ADJMS'),
#   ('de', 'PREP'),
#   ('le', 'PPOBJMS'),
#   ('comprimer', 'VERB'),
#   ('.', 'YPFOR')],
#  [('Ils', 'PPER3MP'),
#   ('seront', 'AUX'),
#   ('donc', 'ADV'),
#   ('persécutés', 'VPPMP'),
#   ('et', 'COCO'),
#   ('rejetés', 'VPPMP'),
#   ('par', 'PREP'),
#   ("l'", 'DET'),
#   ('Antéchrist', 'PROPN'),
#   ('et', 'COCO'),
#   ('son', 'DET'),
#   ('gouvernement', 'NMS'),
#   ('...', 'PUNCT')],
#  [('Nous', 'PREFP'),
#   ('sommes', 'AUX'),
#   ('unanimes', 'ADJ'),
#   (':', 'PUNCT'),
#   ("c'", 'PDEMMS'),
#   ('est', 'AUX'),
#   ('une', 'PINDFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('meilleures', 'ADJFP'),
#   ('expériences', 'NFP'),
#   ('de', 'PREP'),
#   ('gastronomie', 'NFS'),
#   ('japonaise', 'ADJFS'),
#   ('jamais', 'ADV'),
#   ('faite', 'VPPFS'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('année', 'NFS'),
#   ('suivante', 'ADJFS'),
#   ('(', 'PUNCT'),
#   ('1926', 'CHIF'),
#   (')', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('elle', 'PPER3FS'),
#   ('est', 'AUX'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('nombre', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('treize', 'CHIF'),
#   ('jeunes', 'ADJFP'),
#   ('actrices', 'NFP'),
#   ('(', 'PUNCT'),
#   ('dont', 'PREL'),
#   ('Mary', 'PROPN'),
#   ('Astor', 'XFAMIL'),
#   ('et', 'COCO'),
#   ('Joan', 'PROPN'),
#   ('Crawford', 'XFAMIL'),
#   (')', 'PUNCT'),
#   ('recevant', 'VERB'),
#   ('le', 'DETMS'),
#   ('WAMPAS', 'PROPN'),
#   ('Baby', 'NMS'),
#   ('Stars', 'NFP'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('développa', 'VERB'),
#   ('une', 'DINTFS'),
#   ('critique', 'NFS'),
#   ('sérieuse', 'ADJFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('institutions', 'NFP'),
#   ('libérales', 'ADJFP'),
#   ('depuis', 'PREP'),
#   ('le', 'DETMS'),
#   ('milieu', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('années', 'NFP'),
#   ('1990', 'CHIF'),
#   (',', 'PUNCT'),
#   ('durant', 'PREP'),
#   ('lesquelles', 'PRELFP'),
#   ('il', 'PPER3MS'),
#   ('publie', 'VERB'),
#   ('ses', 'DET'),
#   ('premiers', 'ADJMP'),
#   ('articles', 'NMP'),
#   ('académiques', 'ADJMP'),
#   (',', 'PUNCT'),
#   ('en', 'PREP'),
#   ('particulier', 'ADJMS'),
#   ('contre', 'PREP'),
#   ('la', 'DETFS'),
#   ('théorie', 'NFS'),
#   ('politique', 'ADJFS'),
#   ('de', 'PREP'),
#   ('John', 'PROPN'),
#   ('Rawls', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [('Cette', 'PDEMFS'),
#   ('série', 'NFS'),
#   ('de', 'PREP'),
#   ('publications', 'NFP'),
#   ('a', 'AUX'),
#   ('débuté', 'VPPMS'),
#   ('en', 'PREP'),
#   ('1927', 'CHIF'),
#   ('.', 'YPFOR')],
#  ...]

# %%
def train_hmm_pos_tagger(train_sents):
    tagged_sents = [nltk.tag.untag(sent) for sent in train_sents]
    unigram_tagger = nltk.UnigramTagger(train_sents)
    bigram_tagger = nltk.BigramTagger(train_sents, backoff=unigram_tagger)
    trigram_tagger = nltk.TrigramTagger(train_sents, backoff=bigram_tagger)

    return trigram_tagger

hmm_pos_tagger = train_hmm_pos_tagger(train_sents)

# %%
import spacy

#le modèle français
nlp = spacy.load("fr_core_news_sm")

def evaluate_spacy_pos_tagger(test_sents):
    correct = 0
    total = 0

    for sent in test_sents:
        words, gold_tags = zip(*sent)
        doc = nlp(" ".join(words))  # Concaténez les mots en une chaîne de caractères
        tags = [token.pos_ for token in doc]
        for word, gold_tag, tag in zip(words, gold_tags, tags):
            total += 1
            if gold_tag == tag:
                correct += 1

    accuracy = correct / total
    return accuracy

test_texts = [' '.join(sent[0] for sent in sents) for sents in test_sents]
test_docs = list(nlp.pipe(test_texts))
test_spacy_sents = [[(token.text, token.pos_) for token in doc] for doc in test_docs]

test_accuracy = evaluate_spacy_pos_tagger(test_spacy_sents)
print("Test set accuracy:", test_accuracy)
# Out:
# Test set accuracy: 0.977339992600814

# %%
for i in range(10):
    print(f"Phrase {i + 1}:")
    for word, tag in test_spacy_sents[i]:
        print(f"{word}\t{tag}")
    print()
# Out:
# Phrase 1:
# Je	PRON
# sens	VERB
# qu	NUM
# '	PUNCT
# entre	ADP
# ça	PRON
# et	CCONJ
# les	DET
# films	NOUN
# de	ADP
# médecins	NOUN
# et	CCONJ
# scientifiques	ADJ
# fous	ADJ
# que	SCONJ
# nous	PRON
# avons	AUX
# déjà	ADV
# vus	VERB
# ,	PUNCT
# nous	PRON
# pourrions	VERB
# emprunter	VERB
# un	DET
# autre	ADJ
# chemin	NOUN
# pour	ADP
# l	DET
# '	DET
# origine	NOUN
# .	PUNCT
#
# Phrase 2:
# On	PRON
# pourra	VERB
# toujours	ADV
# parler	VERB
# à	ADP
# propos	NOUN
# d	ADP
# '	ADP
# Averroès	NOUN
# de	ADP
# "	PUNCT
# décentrement	NOUN
# du	ADP
# de	ADP
# le	DET
# Sujet	NOUN
# "	PUNCT
# .	PUNCT
#
# Phrase 3:
# «	NOUN
# Il	PRON
# a	AUX
# été	AUX
# largement	ADV
# démontré	VERB
# que	SCONJ
# la	DET
# population	NOUN
# civile	ADJ
# du	ADP
# de	ADP
# le	DET
# territoire	NOUN
# non	ADV
# autonome	ADJ
# du	ADP
# de	ADP
# le	DET
# Sahara	PROPN
# occidental	ADJ
# est	AUX
# l	DET
# '	DET
# objet	NOUN
# de	ADP
# diverses	ADJ
# atteintes	VERB
# aux	ADP
# à	ADP
# les	DET
# droits	NOUN
# humains	ADJ
# ,	PUNCT
# comme	ADP
# la	DET
# détention	NOUN
# arbitraire	ADJ
# ,	PUNCT
# les	DET
# coups	NOUN
# et	CCONJ
# les	DET
# tortures	NOUN
# »	PUNCT
# ,	PUNCT
# écrit	VERB
# l	DET
# '	DET
# ONG	NOUN
# internationale	ADJ
# ,	PUNCT
# implantée	VERB
# dans	ADP
# 35	NUM
# pays	NOUN
# ,	PUNCT
# citée	VERB
# par	ADP
# l	DET
# '	DET
# agence	NOUN
# de	ADP
# presse	NOUN
# sahraouie	ADJ
# .	PUNCT
#
# Phrase 4:
# 1er	ADJ
# :	PUNCT
# début	NOUN
# de	ADP
# la	DET
# présidence	NOUN
# lituanienne	ADJ
# de	ADP
# l	DET
# '	DET
# Organisation	NOUN
# pour	ADP
# la	DET
# Sécurité	NOUN
# et	CCONJ
# la	DET
# Coopération	NOUN
# en	ADP
# Europe	PROPN
# (	PUNCT
# OSCE	PROPN
# )	PUNCT
# (	PUNCT
# jusqu	PROPN
# '	PUNCT
# au	ADP
# à	ADP
# le	DET
# 31	NUM
# décembre	NOUN
# )	PUNCT
# ,	PUNCT
# avant	ADP
# l	DET
# '	DET
# Irlande	PROPN
# (	PUNCT
# 2012	NUM
# )	PUNCT
# et	CCONJ
# l	DET
# '	DET
# Ukraine	PROPN
# (	PUNCT
# 2013	NUM
# )	PUNCT
# .	PUNCT
#
# Phrase 5:
# Et	CCONJ
# pourtant	ADV
# ,	PUNCT
# lors	ADV
# de	ADP
# sa	DET
# première	ADJ
# visite	NOUN
# en	ADP
# Afrique	PROPN
# subsaharienne	ADJ
# ,	PUNCT
# l	DET
# '	PRON
# été	NOUN
# 2007	NUM
# ,	PUNCT
# il	PRON
# montre	VERB
# les	DET
# dents	NOUN
# dans	ADP
# un	DET
# discours	NOUN
# humiliant	VERB
# pour	ADP
# les	DET
# Africains	NOUN
# ,	PUNCT
# prononcé	VERB
# à	ADP
# l	DET
# '	DET
# Université	NOUN
# Cheikh	PROPN
# Anta	PROPN
# Diop	NOUN
# de	ADP
# Dakar	NOUN
# .	PUNCT
#
# Phrase 6:
# Les	DET
# spéculations	NOUN
# autour	ADV
# du	ADP
# de	ADP
# le	DET
# match	NOUN
# sont	AUX
# à	ADP
# leur	DET
# paroxysme	NOUN
# .	PUNCT
#
# Phrase 7:
# Ils	PRON
# ne	ADV
# citent	VERB
# pas	ADV
# son	DET
# nom	NOUN
# ,	PUNCT
# parce	SCONJ
# que	SCONJ
# depuis	ADP
# les	DET
# institutions	NOUN
# on	PRON
# n	ADJ
# '	PUNCT
# attaque	NOUN
# pas	ADV
# un	DET
# membre	NOUN
# de	ADP
# la	DET
# famille	NOUN
# royale	ADJ
# ,	PUNCT
# mais	CCONJ
# c	PRON
# '	PRON
# est	AUX
# à	ADP
# lui	PRON
# qu	PRON
# '	PUNCT
# ils	PRON
# s	PRON
# '	PRON
# en	ADP
# prennent	NOUN
# .	PUNCT
#
# Phrase 8:
# Il	PRON
# y	PRON
# en	PRON
# a	AUX
# qui	PRON
# croient	VERB
# toujours	ADV
# qu	VERB
# '	PUNCT
# ils	PRON
# peuvent	VERB
# jouir	VERB
# de	ADP
# la	DET
# vie	NOUN
# en	ADP
# toute	DET
# tranquillité	NOUN
# de	ADP
# conscience	NOUN
# et	CCONJ
# commettre	VERB
# telle	ADJ
# ou	CCONJ
# telle	ADJ
# indélicatesse	NOUN
# ,	PUNCT
# telle	ADJ
# ou	CCONJ
# telle	ADJ
# grossièreté	NOUN
# ,	PUNCT
# en	ADP
# toute	DET
# sécurité	NOUN
# ,	PUNCT
# parce	SCONJ
# que	SCONJ
# leur	DET
# coeur	NOUN
# serait	AUX
# comme	ADP
# les	DET
# montres	NOUN
# :	PUNCT
# 100	NUM
# %	NOUN
# Waterproof	PROPN
# .	PUNCT
#
# Phrase 9:
# Son	DET
# discours	NOUN
# ,	PUNCT
# inspiré	VERB
# d	ADP
# '	ADP
# une	DET
# pensée	NOUN
# du	ADP
# de	ADP
# le	DET
# Moyen-âge	NOUN
# ,	PUNCT
# a	AUX
# trouvé	VERB
# preneur	ADJ
# .	PUNCT
#
# Phrase 10:
# Pour	ADP
# lui	PRON
# ,	PUNCT
# je	PRON
# crois	VERB
# vraiment	ADV
# que	SCONJ
# l	DET
# '	DET
# essentiel	NOUN
# est	AUX
# ailleurs	ADV
# ,	PUNCT
# dans	ADP
# cette	DET
# contribution	NOUN
# à	ADP
# la	DET
# déstabilisation	NOUN
# de	ADP
# l	DET
# '	DET
# autorité	NOUN
# spirituelle	ADJ
# du	ADP
# de	ADP
# le	DET
# pape	NOUN
# que	PRON
# vous	PRON
# évoquez	VERB
# .	PUNCT

# %%
test_sentence = "Le chat mange la souris."

doc = nlp(test_sentence)

print("Test sentence:")
for token in doc:
    print(f"{token.text}\t{token.pos_}")
# Out:
# Test sentence:
# Le	DET
# chat	NOUN
# mange	VERB
# la	DET
# souris	PROPN
# .	PUNCT
